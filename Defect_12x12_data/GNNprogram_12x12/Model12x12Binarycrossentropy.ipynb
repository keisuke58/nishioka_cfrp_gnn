# %%
import os
import time
import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from torch.utils.tensorboard import SummaryWriter
import seaborn as sns

# デバイス設定
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print(f"GPU is available: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("GPU is not available, using CPU")

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# データフォルダのパス
standardized_data_folder = "/home/nishioka/GNN/Defect_12x12_data/Defect_12x12_Normalized1"
label_data_folder = "/home/nishioka/GNN/Defect_12x12_data/DefectLabels_12x12test2"

# 座標データのロード
x_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/x_2layer_normalized.npy")[:3654]
y_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/y_2layer_normalized.npy")[:3654]
z_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/z_2layer_normalized.npy")[:3654]

# エッジ情報のロード
edges = np.load("/home/nishioka/GNN/BasicdataforGNN/edges_2layer.npy")
edge_index = torch.tensor(edges.T, dtype=torch.long).to(device)

# データとラベルファイルのリストアップ
data_files = [f for f in os.listdir(standardized_data_folder) if f.startswith("Normalized1_Defect12x12_ELNOD")]
label_files = [f for f in os.listdir(label_data_folder) if f.startswith("12x12DefectLabel1_L")]

# 欠陥なしデータのペア
defect_free_pair = ("/home/nishioka/GNN/Defect_4x4_Normalized1/0Normalized1_nodefect_4x4_ELNOD.npy",
                    "/home/nishioka/GNN/DefectLabels_4x4_test1/0DefectLabel_nodefect1.npy")


# 初期のペアリスト
train_pairs = []
val_pairs = []
test_pairs = []

# 欠陥なしデータを追加
for _ in range(8):
    train_pairs.append(defect_free_pair)
val_pairs.append(defect_free_pair)
test_pairs.append(defect_free_pair)

# ペアのデータをカウントして確認
def count_pair_occurrences(pairs, target_pair):
    return pairs.count(target_pair)

train_count = count_pair_occurrences(train_pairs, defect_free_pair)
val_count = count_pair_occurrences(val_pairs, defect_free_pair)
test_count = count_pair_occurrences(test_pairs, defect_free_pair)

print(f"\nDefect-free data occurrences in train_pairs: {train_count} (expected: 8)")
print(f"Defect-free data occurrences in val_pairs: {val_count} (expected: 1)")
print(f"Defect-free data occurrences in test_pairs: {test_count} (expected: 1)")

if train_count == 8 and val_count == 1 and test_count == 1:
    print("\nAll defect-free data pairs are correctly added.")
else:
    print("\nThere is an issue with adding defect-free data pairs.")

# ファイル名から層とブロックを抽出する関数
def extract_layer_block(file_name):
    if file_name.startswith("0"):
        return (0, 0)  # 欠陥なしデータの場合
    try:
        layer_block_str = file_name.split("_")[-1].replace(".npy", "")
        layer_str = layer_block_str.split("L")[1].split("B")[0]
        block_str = layer_block_str.split("B")[1]
        layer = int(layer_str)
        block = int(block_str)
        return (layer, block)
    except (ValueError, IndexError):
        print(f"無効なファイル名の形式: {file_name}")
        return None

# データとラベルのペアを作成
data_label_pairs = {}
for data_file in data_files:
    layer_block = extract_layer_block(data_file)
    if layer_block:
        data_label_pairs[layer_block] = {"data": data_file}

for label_file in label_files:
    layer_block = extract_layer_block(label_file)
    if layer_block and layer_block in data_label_pairs:
        data_label_pairs[layer_block]["label"] = label_file

# 有効なペアのみ取得
valid_pairs = [(v["data"], v["label"]) for k, v in data_label_pairs.items() if "label" in v]

# ランダムにサンプリング
num_samples = 142
random_indices = np.random.choice(len(valid_pairs), num_samples, replace=False)

# サンプルをトレーニングデータとして取得
sampled_train_pairs = [valid_pairs[i] for i in random_indices]

# 残りのデータを取得
remaining_pairs = [valid_pairs[i] for i in range(len(valid_pairs)) if i not in random_indices]

# 残りのデータを1:1でバリデーションとテストに分割
sampled_val_pairs, sampled_test_pairs = train_test_split(remaining_pairs, test_size=0.5, random_state=42)

# 既存のペアリストにサンプリングされたペアを追加
train_pairs.extend(sampled_train_pairs)
val_pairs.extend(sampled_val_pairs)
test_pairs.extend(sampled_test_pairs)

print(f"\nAfter sampling:")
print(f"Train pairs count (including defect-free): {len(train_pairs)}")
print(f"Validation pairs count (including defect-free): {len(val_pairs)}")
print(f"Test pairs count (including defect-free): {len(test_pairs)}")

# データ準備の関数
def prepare_data(pairs):
    sampled_data = []
    sampled_labels = []
    
    for data_file, label_file in pairs:
        data_file_path = os.path.join(standardized_data_folder, data_file)
        label_file_path = os.path.join(label_data_folder, label_file)

        # データとラベルを読み込む
        values = np.load(data_file_path)[:3654]
        label = np.load(label_file_path)[:3654]
        
        # 座標データと応力データを結合してノード特徴量を作成
        node_features = np.vstack((x_coords, y_coords, z_coords, values)).T
        sampled_data.append(node_features)
        sampled_labels.append(label)
    
    # データを結合しテンソルに変換
    sampled_data = np.stack(sampled_data)  # Shape: (num_samples, 3654, 4)
    sampled_labels = np.stack(sampled_labels)  # Shape: (num_samples, 3654)
    
    # PyTorchテンソルに変換
    x = torch.tensor(sampled_data.reshape(-1, 4), dtype=torch.float).to(device)  # Shape: (num_samples*3654, 4)
    y = torch.tensor(sampled_labels.reshape(-1, 1), dtype=torch.float).to(device)  # Shape: (num_samples*3654, 1)
    
    return x, y

# 各データセットを準備
train_x, train_y = prepare_data(train_pairs)
val_x, val_y = prepare_data(val_pairs)
test_x, test_y = prepare_data(test_pairs)

# Dataオブジェクトにまとめる
train_data_list = []
val_data_list = []
test_data_list = []

# サンプル単位でDataオブジェクトを作成
def create_data_list(x, y, num_samples, data_list):
    for i in range(num_samples):
        start = i * 3654
        end = (i + 1) * 3654
        data = Data(x=x[start:end], edge_index=edge_index, y=y[start:end])
        data_list.append(data)

num_train_samples = len(train_pairs)
num_val_samples = len(val_pairs)
num_test_samples = len(test_pairs)

create_data_list(train_x, train_y, num_train_samples, train_data_list)
create_data_list(val_x, val_y, num_val_samples, val_data_list)
create_data_list(test_x, test_y, num_test_samples, test_data_list)

print(f"\nDataset Sizes:")
print(f"Training data size: {len(train_data_list)} samples")
print(f"Validation data size: {len(val_data_list)} samples")
print(f"Test data size: {len(test_data_list)} samples")

# モデルの定義
class GATModel(nn.Module):
    def __init__(self, hidden_channels=64):
        super(GATModel, self).__init__()
        self.conv1 = GATConv(4, hidden_channels, heads=4, concat=True)  # Input features: 4
        self.conv2 = GATConv(hidden_channels * 4, hidden_channels * 2, heads=4, concat=True)
        self.conv3 = GATConv(hidden_channels * 8, hidden_channels * 4, heads=4, concat=True)
        self.conv4 = GATConv(hidden_channels * 16, hidden_channels, heads=4, concat=True)
        self.conv5 = GATConv(hidden_channels * 4, hidden_channels, heads=1, concat=False)  # 最終層はヘッドを1にしconcat=False
        self.fc_defect = nn.Linear(hidden_channels, 1)  # 回帰タスク用に出力1次元

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv3(x, edge_index))
        x = F.relu(self.conv4(x, edge_index))
        x = F.relu(self.conv5(x, edge_index))
        x = self.fc_defect(x)
        return torch.sigmoid(x)  # バイナリ分類用にSigmoid関数を追加

# Xavier初期化関数
def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight)
    elif isinstance(m, GATConv):
        if m.lin_src is not None:
            torch.nn.init.xavier_uniform_(m.lin_src.weight)
        if m.lin_dst is not None:
            torch.nn.init.xavier_uniform_(m.lin_dst.weight)

# モデル、損失関数、オプティマイザの定義
hidden_channels = 64
learning_rate = 0.001
batch_size = 32
epochs = 2000
weight_decay = 5e-4
patience = 100  # Early Stopping用

model = GATModel(hidden_channels=hidden_channels).to(device)
model.apply(init_weights)

loss_fn = nn.BCELoss()  # バイナリクロスエントロピー損失
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# TensorBoardの初期化
writer = SummaryWriter(log_dir=f'/home/nishioka/GNN/Defect_12x12_data/GNNlogs/{timestamp}')

# EarlyStopping クラス定義
class EarlyStopping:
    """Early stopping utility to stop training when validation loss doesn't improve."""
    def __init__(self, patience=patience, verbose=False, delta=0, path='checkpoint.pth', trace_func=print):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# EarlyStoppingクラスのインスタンス作成
early_stopping = EarlyStopping(
    patience=patience,
    verbose=True,
    path=f'/home/nishioka/GNN/Defect_12x12_data/GNNmodel/GATModel_best_{timestamp}.pth'
)

# DataLoaderの作成
train_loader = DataLoader(train_data_list, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data_list, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_data_list, batch_size=batch_size, shuffle=False)

# 学習ループ
train_losses = []
val_losses = []
start_time = time.time()

print("\n--- Training Start ---")

for epoch in range(1, epochs + 1):
    model.train()
    total_train_loss = 0

    for batch in train_loader:
        batch = batch.to(device)
        optimizer.zero_grad()
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1).float())
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()
    
    avg_train_loss = total_train_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    
    # 検証ステップ
    model.eval()
    total_val_loss = 0
    with torch.no_grad():
        for batch in val_loader:
            batch = batch.to(device)
            out = model(batch)
            loss = loss_fn(out, batch.y.view(-1, 1).float())
            total_val_loss += loss.item()
    
    avg_val_loss = total_val_loss / len(val_loader)
    val_losses.append(avg_val_loss)
    
    # TensorBoardに損失を記録
    writer.add_scalar('Loss/train', avg_train_loss, epoch)
    writer.add_scalar('Loss/val', avg_val_loss, epoch)
    
    # Early Stoppingに現在のバリデーション損失とモデルを渡す
    early_stopping(avg_val_loss, model)
    
    # Early StoppingがTrueなら訓練を終了
    if early_stopping.early_stop:
        print(f"Early stopping at epoch {epoch}")
        break
    
    # 1, 10, 30, 50, 100, 150, 200, 250... のタイミングで結果を出力
    if epoch == 1 or epoch == 10 or epoch == 30 or (epoch % 50 == 0):
        elapsed_time = time.time() - start_time
        print(f'Epoch {epoch}, Train Loss: {avg_train_loss:.6f}, Val Loss: {avg_val_loss:.6f}, Time: {elapsed_time:.2f}s')

# 学習時間の計測終了
elapsed_time = time.time() - start_time
print(f"\nTotal training time: {elapsed_time:.2f} seconds")

# 最良のモデルをロード
model.load_state_dict(torch.load(early_stopping.path))
model.eval()

# テストデータでの評価
test_loss = 0
test_preds = []
test_targets = []
with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1).float())
        test_loss += loss.item()
        test_preds.append(out.cpu().numpy())
        test_targets.append(batch.y.cpu().numpy())

test_loss /= len(test_loader)
test_preds = np.concatenate(test_preds)
test_targets = np.concatenate(test_targets)

# 評価指標の計算
rmse = np.sqrt(mean_squared_error(test_targets, test_preds))
mae = mean_absolute_error(test_targets, test_preds)
r2 = r2_score(test_targets, test_preds)

print(f'\nTest Loss: {test_loss:.6f}, RMSE: {rmse:.6f}, MAE: {mae:.6f}, R2 Score: {r2:.6f}')

# テスト損失をTensorBoardに記録
writer.add_scalar('Loss/test', test_loss, epoch)

# 損失をプロット
plt.figure(figsize=(12, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', color='blue')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', color='orange')
plt.yscale('log')  # 対数スケール
plt.xlabel('Epoch')
plt.ylabel('Loss (Log Scale)')
plt.title(f'Training and Validation Loss GATModel - ({timestamp})')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.savefig(f'/home/nishioka/GNN/Defect_12x12_data/GNNmodelgraphfig/loss_fig_GATModel_{timestamp}.png')
plt.show()

# パラメータテーブルの作成と保存
fig, ax = plt.subplots(figsize=(10, 6))
ax.axis('off')

# データ
table_data = [
    ["Model", "GATModel"],
    ["Hidden Channels", hidden_channels],
    ["Learning Rate", learning_rate],
    ["Batch Size", batch_size],
    ["Epochs", epoch],
    ["Weight Decay", weight_decay],
    ["Patience", patience],
    ["Training Samples", num_train_samples],
    ["Validation Samples", num_val_samples],
    ["Test Samples", num_test_samples]
]

# テーブルの作成
table = ax.table(cellText=table_data, colLabels=["Parameter", "Value"], loc="center", cellLoc="center")
table.scale(1.5, 1.5)
table.set_fontsize(12)

# 保存
plt.savefig(f'/home/nishioka/GNN/Defect_12x12_data/GNNmodelgraphfig/parameter_table_{timestamp}.png')
plt.show()

# モデルとハイパーパラメータをJSONに保存
model_params = {
    'model': 'GATModel',
    'hidden_channels': hidden_channels,
    'learning_rate': learning_rate,
    'batch_size': batch_size,
    'epochs': epoch,
    'weight_decay': weight_decay,
    'patience': patience
}
with open(f'/home/nishioka/GNN/Defect_12x12_data/GNNmodel/{type(model).__name__}_params_{timestamp}.json', 'w') as f:
    json.dump(model_params, f, indent=4)

# 損失とハイパーパラメータ情報をCSVに保存
loss_data = pd.DataFrame({
    'Epoch': range(1, len(train_losses) + 1),
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})
loss_data.to_csv(f'/home/nishioka/GNN/Defect_12x12_data/GNNmodelcsv/loss_data_{timestamp}.csv', index=False)

# テスト損失の保存
test_loss_data = pd.DataFrame({
    'Test Loss': [test_loss],
    'RMSE': [rmse],
    'MAE': [mae],
    'R2 Score': [r2]
})
test_loss_data.to_csv(f'/home/nishioka/GNN/Defect_12x12_data/GNNmodelcsv/test_loss_{timestamp}.csv', index=False)

# モデルの保存（ファイル名にタイムスタンプを追加）
torch.save(model.state_dict(), f'/home/nishioka/GNN/Defect_12x12_data/GNNmodel/GATModel_final_{test_loss:.6f}_{timestamp}.pth')
torch.save(model.state_dict(), f'/home/nishioka/GNN/Defect_12x12_data/GNNmodelweights/GATModel_weights_{test_loss:.6f}_{timestamp}.pth')

# TensorBoardのWriterを閉じる
writer.close()

# 最終的なサマリーの表示
print("\nTraining Summary:")
print(f"Total Epochs Run: {epoch}")
if early_stopping.early_stop:
    print(f"Early stopping at epoch {epoch}")
else:
    print("Training completed without early stopping.")
print(f"Final Training Loss: {train_losses[-1]:.6f}")
print(f"Best Validation Loss: {early_stopping.val_loss_min:.6f}")
print(f"Test Loss: {test_loss:.6f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")
print(f"Mean Absolute Error (MAE): {mae:.6f}")
print(f"R2 Score: {r2:.6f}")
print(f"Total Training Time: {elapsed_time:.2f} seconds")
# Out:
# GPU is available: NVIDIA GeForce RTX 3090
#
# Defect-free data occurrences in train_pairs: 8 (expected: 8)
# Defect-free data occurrences in val_pairs: 1 (expected: 1)
# Defect-free data occurrences in test_pairs: 1 (expected: 1)
#
# All defect-free data pairs are correctly added.
#
# After sampling:
# Train pairs count (including defect-free): 150
# Validation pairs count (including defect-free): 20
# Test pairs count (including defect-free): 20
#
# Dataset Sizes:
# Training data size: 150 samples
# Validation data size: 20 samples
# Test data size: 20 samples
#
# --- Training Start ---
# Validation loss decreased (inf --> 0.193251). Saving model...
# Epoch 1, Train Loss: 0.479844, Val Loss: 0.193251, Time: 0.70s
# Validation loss decreased (0.193251 --> 0.171053). Saving model...
# Validation loss decreased (0.171053 --> 0.166347). Saving model...
# Validation loss decreased (0.166347 --> 0.156375). Saving model...
# Validation loss decreased (0.156375 --> 0.137697). Saving model...
# Validation loss decreased (0.137697 --> 0.128992). Saving model...
# Validation loss decreased (0.128992 --> 0.123816). Saving model...
# Validation loss decreased (0.123816 --> 0.113199). Saving model...
# Validation loss decreased (0.113199 --> 0.110608). Saving model...
# Epoch 10, Train Loss: 0.114998, Val Loss: 0.110608, Time: 6.88s
# Validation loss decreased (0.110608 --> 0.103067). Saving model...
# Validation loss decreased (0.103067 --> 0.102929). Saving model...
# Validation loss decreased (0.102929 --> 0.097689). Saving model...
# Validation loss decreased (0.097689 --> 0.096849). Saving model...
# Validation loss decreased (0.096849 --> 0.092545). Saving model...
# Validation loss decreased (0.092545 --> 0.091862). Saving model...
# Validation loss decreased (0.091862 --> 0.090580). Saving model...
# Validation loss decreased (0.090580 --> 0.089834). Saving model...
# Validation loss decreased (0.089834 --> 0.089828). Saving model...
# Validation loss decreased (0.089828 --> 0.089715). Saving model...
# Validation loss decreased (0.089715 --> 0.089597). Saving model...
# Validation loss decreased (0.089597 --> 0.089470). Saving model...
# Validation loss decreased (0.089470 --> 0.088410). Saving model...
# Epoch 30, Train Loss: 0.093582, Val Loss: 0.088410, Time: 20.40s
# Validation loss decreased (0.088410 --> 0.088055). Saving model...
# Validation loss decreased (0.088055 --> 0.088010). Saving model...
# Validation loss decreased (0.088010 --> 0.087564). Saving model...
# Validation loss decreased (0.087564 --> 0.087050). Saving model...
# Validation loss decreased (0.087050 --> 0.086987). Saving model...
# Epoch 50, Train Loss: 0.090880, Val Loss: 0.086987, Time: 33.53s
# Validation loss decreased (0.086987 --> 0.086921). Saving model...
# Validation loss decreased (0.086921 --> 0.086223). Saving model...
# Validation loss decreased (0.086223 --> 0.085682). Saving model...
# Validation loss decreased (0.085682 --> 0.085529). Saving model...
# Validation loss decreased (0.085529 --> 0.085049). Saving model...
# Validation loss decreased (0.085049 --> 0.085014). Saving model...
# Validation loss decreased (0.085014 --> 0.084351). Saving model...
# Validation loss decreased (0.084351 --> 0.084145). Saving model...
# Validation loss decreased (0.084145 --> 0.083824). Saving model...
# Validation loss decreased (0.083824 --> 0.083434). Saving model...
# Validation loss decreased (0.083434 --> 0.083290). Saving model...
# Validation loss decreased (0.083290 --> 0.083128). Saving model...
# Epoch 100, Train Loss: 0.088823, Val Loss: 0.085913, Time: 66.35s
# Validation loss decreased (0.083128 --> 0.082701). Saving model...
# Validation loss decreased (0.082701 --> 0.082404). Saving model...
# Validation loss decreased (0.082404 --> 0.082137). Saving model...
# Validation loss decreased (0.082137 --> 0.081616). Saving model...
# Validation loss decreased (0.081616 --> 0.081611). Saving model...
# Validation loss decreased (0.081611 --> 0.081206). Saving model...
# Validation loss decreased (0.081206 --> 0.080770). Saving model...
# Validation loss decreased (0.080770 --> 0.080720). Saving model...
# Validation loss decreased (0.080720 --> 0.080700). Saving model...
# Validation loss decreased (0.080700 --> 0.080678). Saving model...
# Validation loss decreased (0.080678 --> 0.080158). Saving model...
# Validation loss decreased (0.080158 --> 0.080007). Saving model...
# Validation loss decreased (0.080007 --> 0.079941). Saving model...
# Epoch 150, Train Loss: 0.083581, Val Loss: 0.082764, Time: 99.28s
# Validation loss decreased (0.079941 --> 0.079781). Saving model...
# Validation loss decreased (0.079781 --> 0.079620). Saving model...
# Validation loss decreased (0.079620 --> 0.079568). Saving model...
# Validation loss decreased (0.079568 --> 0.079265). Saving model...
# Validation loss decreased (0.079265 --> 0.079064). Saving model...
# Validation loss decreased (0.079064 --> 0.078953). Saving model...
# Epoch 200, Train Loss: 0.082261, Val Loss: 0.079062, Time: 131.95s
# Validation loss decreased (0.078953 --> 0.078830). Saving model...
# Validation loss decreased (0.078830 --> 0.078750). Saving model...
# Validation loss decreased (0.078750 --> 0.078696). Saving model...
# Validation loss decreased (0.078696 --> 0.078615). Saving model...
# Epoch 250, Train Loss: 0.082303, Val Loss: 0.078629, Time: 164.53s
# Validation loss decreased (0.078615 --> 0.078453). Saving model...
# Validation loss decreased (0.078453 --> 0.078395). Saving model...
# Validation loss decreased (0.078395 --> 0.078327). Saving model...
# Validation loss decreased (0.078327 --> 0.078267). Saving model...
# Epoch 300, Train Loss: 0.081564, Val Loss: 0.078401, Time: 197.14s
# Validation loss decreased (0.078267 --> 0.077978). Saving model...
# Validation loss decreased (0.077978 --> 0.077958). Saving model...
# Validation loss decreased (0.077958 --> 0.077945). Saving model...
# Validation loss decreased (0.077945 --> 0.077906). Saving model...
# Validation loss decreased (0.077906 --> 0.077787). Saving model...
# Validation loss decreased (0.077787 --> 0.077704). Saving model...
# Epoch 350, Train Loss: 0.081735, Val Loss: 0.077985, Time: 229.84s
# Validation loss decreased (0.077704 --> 0.077691). Saving model...
# Validation loss decreased (0.077691 --> 0.077676). Saving model...
# Epoch 400, Train Loss: 0.080766, Val Loss: 0.078665, Time: 262.35s
# Validation loss decreased (0.077676 --> 0.077638). Saving model...
# Validation loss decreased (0.077638 --> 0.077569). Saving model...
# Validation loss decreased (0.077569 --> 0.077508). Saving model...
# Validation loss decreased (0.077508 --> 0.077472). Saving model...
# Validation loss decreased (0.077472 --> 0.077413). Saving model...
# Epoch 450, Train Loss: 0.080119, Val Loss: 0.078950, Time: 295.02s
# Validation loss decreased (0.077413 --> 0.077394). Saving model...
# Validation loss decreased (0.077394 --> 0.077359). Saving model...
# Epoch 500, Train Loss: 0.081478, Val Loss: 0.077793, Time: 327.55s
# Validation loss decreased (0.077359 --> 0.077357). Saving model...
# Validation loss decreased (0.077357 --> 0.077336). Saving model...
# Validation loss decreased (0.077336 --> 0.077308). Saving model...
# Validation loss decreased (0.077308 --> 0.077274). Saving model...
# Epoch 550, Train Loss: 0.080347, Val Loss: 0.077574, Time: 360.14s
# Validation loss decreased (0.077274 --> 0.077218). Saving model...
# Validation loss decreased (0.077218 --> 0.077207). Saving model...
# Validation loss decreased (0.077207 --> 0.077199). Saving model...
# Epoch 600, Train Loss: 0.080491, Val Loss: 0.077244, Time: 392.71s
# Validation loss decreased (0.077199 --> 0.077167). Saving model...
# Validation loss decreased (0.077167 --> 0.077166). Saving model...
# Validation loss decreased (0.077166 --> 0.077154). Saving model...
# Validation loss decreased (0.077154 --> 0.077068). Saving model...
# Epoch 650, Train Loss: 0.080951, Val Loss: 0.078994, Time: 425.31s
# Validation loss decreased (0.077068 --> 0.077057). Saving model...
# Validation loss decreased (0.077057 --> 0.076928). Saving model...
# Epoch 700, Train Loss: 0.080591, Val Loss: 0.077155, Time: 457.82s
# Validation loss decreased (0.076928 --> 0.076800). Saving model...
# Validation loss decreased (0.076800 --> 0.076700). Saving model...
# Epoch 750, Train Loss: 0.080758, Val Loss: 0.076949, Time: 490.32s
# Validation loss decreased (0.076700 --> 0.076674). Saving model...
# Validation loss decreased (0.076674 --> 0.076659). Saving model...
# Epoch 800, Train Loss: 0.081120, Val Loss: 0.076659, Time: 522.86s
# Validation loss decreased (0.076659 --> 0.076619). Saving model...
# Validation loss decreased (0.076619 --> 0.076596). Saving model...
# Validation loss decreased (0.076596 --> 0.076489). Saving model...
# Epoch 850, Train Loss: 0.080844, Val Loss: 0.076553, Time: 555.46s
# Validation loss decreased (0.076489 --> 0.076486). Saving model...
# Validation loss decreased (0.076486 --> 0.076447). Saving model...
# Validation loss decreased (0.076447 --> 0.076392). Saving model...
# Epoch 900, Train Loss: 0.080533, Val Loss: 0.077500, Time: 588.08s
# Validation loss decreased (0.076392 --> 0.076385). Saving model...
# Validation loss decreased (0.076385 --> 0.076385). Saving model...
# Validation loss decreased (0.076385 --> 0.076304). Saving model...
# Epoch 950, Train Loss: 0.079152, Val Loss: 0.078777, Time: 620.69s
# Validation loss decreased (0.076304 --> 0.076256). Saving model...
# Validation loss decreased (0.076256 --> 0.076203). Saving model...
# Validation loss decreased (0.076203 --> 0.076074). Saving model...
# Validation loss decreased (0.076074 --> 0.076064). Saving model...
# Validation loss decreased (0.076064 --> 0.075951). Saving model...
# Epoch 1000, Train Loss: 0.079092, Val Loss: 0.076087, Time: 653.41s
# Validation loss decreased (0.075951 --> 0.075897). Saving model...
# Validation loss decreased (0.075897 --> 0.075775). Saving model...
# Epoch 1050, Train Loss: 0.079289, Val Loss: 0.080294, Time: 685.97s
# Validation loss decreased (0.075775 --> 0.075756). Saving model...
# Validation loss decreased (0.075756 --> 0.075748). Saving model...
# Validation loss decreased (0.075748 --> 0.075657). Saving model...
# Validation loss decreased (0.075657 --> 0.075602). Saving model...
# Validation loss decreased (0.075602 --> 0.075518). Saving model...
# Epoch 1100, Train Loss: 0.078090, Val Loss: 0.077372, Time: 718.66s
# Validation loss decreased (0.075518 --> 0.075397). Saving model...
# Validation loss decreased (0.075397 --> 0.075280). Saving model...
# Validation loss decreased (0.075280 --> 0.075262). Saving model...
# Validation loss decreased (0.075262 --> 0.075187). Saving model...
# Validation loss decreased (0.075187 --> 0.075128). Saving model...
# Epoch 1150, Train Loss: 0.078796, Val Loss: 0.075128, Time: 751.35s
# Validation loss decreased (0.075128 --> 0.075091). Saving model...
# Validation loss decreased (0.075091 --> 0.074791). Saving model...
# Epoch 1200, Train Loss: 0.078214, Val Loss: 0.078415, Time: 783.88s
# Validation loss decreased (0.074791 --> 0.074670). Saving model...
# Validation loss decreased (0.074670 --> 0.074670). Saving model...
# Validation loss decreased (0.074670 --> 0.074401). Saving model...
# Epoch 1250, Train Loss: 0.077747, Val Loss: 0.074450, Time: 816.48s
# Validation loss decreased (0.074401 --> 0.074370). Saving model...
# Validation loss decreased (0.074370 --> 0.074310). Saving model...
# Validation loss decreased (0.074310 --> 0.074260). Saving model...
# Validation loss decreased (0.074260 --> 0.074227). Saving model...
# Epoch 1300, Train Loss: 0.077662, Val Loss: 0.076892, Time: 849.13s
# Validation loss decreased (0.074227 --> 0.074218). Saving model...
# Validation loss decreased (0.074218 --> 0.074159). Saving model...
# Validation loss decreased (0.074159 --> 0.074110). Saving model...
# Validation loss decreased (0.074110 --> 0.074086). Saving model...
# Epoch 1350, Train Loss: 0.077967, Val Loss: 0.074596, Time: 881.75s
# Validation loss decreased (0.074086 --> 0.073991). Saving model...
# Epoch 1400, Train Loss: 0.077109, Val Loss: 0.075294, Time: 914.25s
# Validation loss decreased (0.073991 --> 0.073932). Saving model...
# Epoch 1450, Train Loss: 0.077180, Val Loss: 0.073932, Time: 946.77s
# Validation loss decreased (0.073932 --> 0.073900). Saving model...
# Validation loss decreased (0.073900 --> 0.073899). Saving model...
# Epoch 1500, Train Loss: 0.076797, Val Loss: 0.074062, Time: 979.33s
# Validation loss decreased (0.073899 --> 0.073871). Saving model...
# Validation loss decreased (0.073871 --> 0.073788). Saving model...
# Validation loss decreased (0.073788 --> 0.073768). Saving model...
# Validation loss decreased (0.073768 --> 0.073753). Saving model...
# Epoch 1550, Train Loss: 0.076846, Val Loss: 0.074055, Time: 1011.98s
# Validation loss decreased (0.073753 --> 0.073750). Saving model...
# Epoch 1600, Train Loss: 0.076984, Val Loss: 0.073852, Time: 1044.48s
# Validation loss decreased (0.073750 --> 0.073732). Saving model...
# Validation loss decreased (0.073732 --> 0.073628). Saving model...
# Validation loss decreased (0.073628 --> 0.073613). Saving model...
# Epoch 1650, Train Loss: 0.076578, Val Loss: 0.073763, Time: 1077.06s
# Validation loss decreased (0.073613 --> 0.073591). Saving model...
# Validation loss decreased (0.073591 --> 0.073556). Saving model...
# Epoch 1700, Train Loss: 0.076684, Val Loss: 0.074101, Time: 1109.65s
# Validation loss decreased (0.073556 --> 0.073529). Saving model...
# Epoch 1750, Train Loss: 0.076949, Val Loss: 0.075883, Time: 1142.16s
# Validation loss decreased (0.073529 --> 0.073528). Saving model...
# Validation loss decreased (0.073528 --> 0.073524). Saving model...
# Validation loss decreased (0.073524 --> 0.073508). Saving model...
# Epoch 1800, Train Loss: 0.076380, Val Loss: 0.073510, Time: 1174.78s
# Validation loss decreased (0.073508 --> 0.073494). Saving model...
# Epoch 1850, Train Loss: 0.076032, Val Loss: 0.073494, Time: 1207.30s
# Validation loss decreased (0.073494 --> 0.073470). Saving model...
# Validation loss decreased (0.073470 --> 0.073458). Saving model...
# Validation loss decreased (0.073458 --> 0.073422). Saving model...
# Epoch 1900, Train Loss: 0.076736, Val Loss: 0.074241, Time: 1239.94s
# Validation loss decreased (0.073422 --> 0.073387). Saving model...
# Validation loss decreased (0.073387 --> 0.073344). Saving model...
# Epoch 1950, Train Loss: 0.075975, Val Loss: 0.075999, Time: 1272.54s
# Validation loss decreased (0.073344 --> 0.073310). Saving model...
# Epoch 2000, Train Loss: 0.076476, Val Loss: 0.073555, Time: 1305.08s
#
# Total training time: 1305.08 seconds
#
# Test Loss: 0.069664, RMSE: 0.083865, MAE: 0.029363, R2 Score: 0.779735
# Training Summary:
# Total Epochs Run: 2000
# Training completed without early stopping.
# Final Training Loss: 0.076476
# Best Validation Loss: 0.073310
# Test Loss: 0.069664
# Root Mean Squared Error (RMSE): 0.083865
# Mean Absolute Error (MAE): 0.029363
# R2 Score: 0.779735
# Total Training Time: 1305.08 seconds

# %%
import numpy as np
np.save(f'/home/nishioka/GNN/Defect_12x12_data/trainindata_confirm1/train_pairs.npy', train_pairs)
np.save(f'/home/nishioka/GNN/Defect_12x12_data/trainindata_confirm1/val_pairs.npy', val_pairs)
np.save(f'/home/nishioka/GNN/Defect_12x12_data/trainindata_confirm1/test_pairs.npy', test_pairs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 np.save(f'/home/nishioka/GNN/Defect_12x12_data/trainindata_confirm1/train_pairs.npy', train_pairs)
#       3 np.save(f'/home/nishioka/GNN/Defect_12x12_data/trainindata_confirm1/val_pairs.npy', val_pairs)
#       4 np.save(f'/home/nishioka/GNN/Defect_12x12_data/trainindata_confirm1/test_pairs.npy', test_pairs)
#
# NameError: name 'train_pairs' is not defined
