# %%
import os
import time
import json
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from torch.utils.tensorboard import SummaryWriter

# デバイス設定
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print(f"GPU is available: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("GPU is not available, using CPU")

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# データフォルダのパス
standardized_data_folder = "/home/nishioka/GNN/Defect_12x12_data/Defect_12x12_Normalized1"
label_data_folder = "/home/nishioka/GNN/Defect_12x12_data/DefectLabels_12x12test2"

# 座標データのロード
x_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/x_2layer_normalized.npy")[:3654]
y_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/y_2layer_normalized.npy")[:3654]
z_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/z_2layer_normalized.npy")[:3654]

# エッジ情報のロード
edges = np.load("/home/nishioka/GNN/BasicdataforGNN/edges_2layer.npy")
edge_index = torch.tensor(edges.T, dtype=torch.long).to(device)

# データとラベルファイルのリストアップ
data_files = [f for f in os.listdir(standardized_data_folder) if f.startswith("Normalized1_Defect12x12_ELNOD")]
label_files = [f for f in os.listdir(label_data_folder) if f.startswith("12x12DefectLabel1_L")]

# 欠陥なしデータのペア
defect_free_pair = ("/home/nishioka/GNN/Defect_4x4_Normalized1/0Normalized1_nodefect_4x4_ELNOD.npy",
                    "/home/nishioka/GNN/DefectLabels_4x4_test1/0DefectLabel_nodefect1.npy")

# 初期のペアリスト
train_pairs = []
val_pairs = []
test_pairs = []

# 欠陥なしデータを追加
for _ in range(8):
    train_pairs.append(defect_free_pair)
val_pairs.append(defect_free_pair)
test_pairs.append(defect_free_pair)

# ペアのデータをカウントして確認
def count_pair_occurrences(pairs, target_pair):
    return pairs.count(target_pair)

train_count = count_pair_occurrences(train_pairs, defect_free_pair)
val_count = count_pair_occurrences(val_pairs, defect_free_pair)
test_count = count_pair_occurrences(test_pairs, defect_free_pair)

print(f"\nDefect-free data occurrences in train_pairs: {train_count} (expected: 8)")
print(f"Defect-free data occurrences in val_pairs: {val_count} (expected: 1)")
print(f"Defect-free data occurrences in test_pairs: {test_count} (expected: 1)")

if train_count == 8 and val_count == 1 and test_count == 1:
    print("\nAll defect-free data pairs are correctly added.")
else:
    print("\nThere is an issue with adding defect-free data pairs.")

# ファイル名から層とブロックを抽出する関数
def extract_layer_block(file_name):
    if file_name.startswith("0"):
        return (0, 0)  # 欠陥なしデータの場合
    try:
        layer_block_str = file_name.split("_")[-1].replace(".npy", "")
        layer_str = layer_block_str.split("L")[1].split("B")[0]
        block_str = layer_block_str.split("B")[1]
        layer = int(layer_str)
        block = int(block_str)
        return (layer, block)
    except (ValueError, IndexError):
        print(f"無効なファイル名の形式: {file_name}")
        return None

# データとラベルのペアを作成
data_label_pairs = {}
for data_file in data_files:
    layer_block = extract_layer_block(data_file)
    if layer_block:
        data_label_pairs[layer_block] = {"data": data_file}

for label_file in label_files:
    layer_block = extract_layer_block(label_file)
    if layer_block and layer_block in data_label_pairs:
        data_label_pairs[layer_block]["label"] = label_file

# 有効なペアのみ取得
valid_pairs = [(v["data"], v["label"]) for k, v in data_label_pairs.items() if "label" in v]

# ランダムにサンプリング
num_samples = 142
random_indices = np.random.choice(len(valid_pairs), num_samples, replace=False)

# サンプルをトレーニングデータとして取得
sampled_train_pairs = [valid_pairs[i] for i in random_indices]

# 残りのデータを取得
remaining_pairs = [valid_pairs[i] for i in range(len(valid_pairs)) if i not in random_indices]

# 残りのデータを1:1でバリデーションとテストに分割
sampled_val_pairs, sampled_test_pairs = train_test_split(remaining_pairs, test_size=0.5, random_state=42)

# 既存のペアリストにサンプリングされたペアを追加
train_pairs.extend(sampled_train_pairs)
val_pairs.extend(sampled_val_pairs)
test_pairs.extend(sampled_test_pairs)

print(f"\nAfter sampling:")
print(f"Train pairs count (including defect-free): {len(train_pairs)}")
print(f"Validation pairs count (including defect-free): {len(val_pairs)}")
print(f"Test pairs count (including defect-free): {len(test_pairs)}")

# データ準備の関数
def prepare_data(pairs):
    sampled_data = []
    sampled_labels = []
    
    for data_file, label_file in pairs:
        data_file_path = os.path.join(standardized_data_folder, data_file)
        label_file_path = os.path.join(label_data_folder, label_file)

        # データとラベルを読み込む
        values = np.load(data_file_path)[:3654]
        label = np.load(label_file_path)[:3654]
        
        # 座標データと強度データを結合してノード特徴量を作成
        node_features = np.vstack((x_coords, y_coords, z_coords, values)).T
        sampled_data.append(node_features)
        sampled_labels.append(label)
    
    # データを結合しテンソルに変換
    sampled_data = np.stack(sampled_data)  # Shape: (num_samples, 3654, 4)
    sampled_labels = np.stack(sampled_labels)  # Shape: (num_samples, 3654)
    
    # PyTorchテンソルに変換
    x = torch.tensor(sampled_data.reshape(-1, 4), dtype=torch.float).to(device)  # Shape: (num_samples*3654, 4)
    y = torch.tensor(sampled_labels.reshape(-1, 1), dtype=torch.float).to(device)  # Shape: (num_samples*3654, 1)
    
    return x, y

# 各データセットを準備
train_x, train_y = prepare_data(train_pairs)
val_x, val_y = prepare_data(val_pairs)
test_x, test_y = prepare_data(test_pairs)

# Dataオブジェクトにまとめる
train_data_list = []
val_data_list = []
test_data_list = []

# サンプル単位でDataオブジェクトを作成
def create_data_list(x, y, num_samples, data_list):
    for i in range(num_samples):
        start = i * 3654
        end = (i + 1) * 3654
        data = Data(x=x[start:end], edge_index=edge_index, y=y[start:end])
        data_list.append(data)

num_train_samples = len(train_pairs)
num_val_samples = len(val_pairs)
num_test_samples = len(test_pairs)

create_data_list(train_x, train_y, num_train_samples, train_data_list)
create_data_list(val_x, val_y, num_val_samples, val_data_list)
create_data_list(test_x, test_y, num_test_samples, test_data_list)

print(f"\nDataset Sizes:")
print(f"Training data size: {len(train_data_list)} samples")
print(f"Validation data size: {len(val_data_list)} samples")
print(f"Test data size: {len(test_data_list)} samples")

# モデルの定義
class GATModel(nn.Module):
    def __init__(self, hidden_channels=64):
        super(GATModel, self).__init__()
        self.conv1 = GATConv(4, hidden_channels, heads=4, concat=True)  # Input features: 4
        self.conv2 = GATConv(hidden_channels * 4, hidden_channels * 2, heads=4, concat=True)
        self.conv3 = GATConv(hidden_channels * 8, hidden_channels * 4, heads=4, concat=True)
        self.conv4 = GATConv(hidden_channels * 16, hidden_channels, heads=4, concat=True)
        self.conv5 = GATConv(hidden_channels * 4, hidden_channels, heads=1, concat=False)  # 最終層はヘッドを1にしconcat=False
        self.fc_defect = nn.Linear(hidden_channels, 1)  # 転射タスク用に出力1次元

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv3(x, edge_index))
        x = F.relu(self.conv4(x, edge_index))
        x = F.relu(self.conv5(x, edge_index))
        x = self.fc_defect(x)
        return torch.sigmoid(x)  # バイナリ分類用にSigmoid関数を追加

# Xavier初期化関数
def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight)
    elif isinstance(m, GATConv):
        if m.lin_src is not None:
            torch.nn.init.xavier_uniform_(m.lin_src.weight)
        if m.lin_dst is not None:
            torch.nn.init.xavier_uniform_(m.lin_dst.weight)

# モデル、損失関数、オプティマイザの定義
hidden_channels = 64
learning_rate = 0.001
batch_size = 32
epochs = 2000
weight_decay = 5e-4
patience = 100  # Early Stopping用

model = GATModel(hidden_channels=hidden_channels).to(device)
model.apply(init_weights)

loss_fn = nn.BCELoss()  # バイナリクロスエントロピー損失
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# TensorBoardの初期化
writer = SummaryWriter(log_dir=f'/home/nishioka/GNN/Defect_12x12_data/GNNlogs/{timestamp}')

# EarlyStopping クラス定義
class EarlyStopping:
    """Early stopping utility to stop training when validation loss doesn't improve."""
    def __init__(self, patience=patience, verbose=False, delta=0, path='checkpoint.pth', trace_func=print):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# EarlyStoppingクラスのインスタンス作成
early_stopping = EarlyStopping(
    patience=patience,
    verbose=True,
    path=f'/home/nishioka/GNN/Defect_12x12_data/GNNmodel/GATModel_best_{timestamp}.pth'
)

# DataLoaderの作成
train_loader = DataLoader(train_data_list, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data_list, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_data_list, batch_size=batch_size, shuffle=False)

# 学習ループ
train_losses = []
val_losses = []
start_time = time.time()

print("\n--- Training Start ---")

for epoch in range(1, epochs + 1):
    model.train()
    total_train_loss = 0

    for batch in train_loader:
        batch = batch.to(device)
        optimizer.zero_grad()
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1).float())
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()
    
    avg_train_loss = total_train_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    
    # 検証ステップ
    model.eval()
    total_val_loss = 0
    with torch.no_grad():
        for batch in val_loader:
            batch = batch.to(device)
            out = model(batch)
            loss = loss_fn(out, batch.y.view(-1, 1).float())
            total_val_loss += loss.item()
    
    avg_val_loss = total_val_loss / len(val_loader)
    val_losses.append(avg_val_loss)
    
    # TensorBoardに損失を記録
    writer.add_scalar('Loss/train', avg_train_loss, epoch)
    writer.add_scalar('Loss/val', avg_val_loss, epoch)
    
    # Early Stoppingに現在のバリデーション損失とモデルを渡す
    early_stopping(avg_val_loss, model)
    
    # Early StoppingがTrueなら訓練を終了
    if early_stopping.early_stop:
        print(f"Early stopping at epoch {epoch}")
        break
    
    # 1, 10, 30, 50, 100, 150, 200, 250... のタイミングで結果を出力
    if epoch == 1 or epoch == 10 or epoch == 30 or (epoch % 50 == 0):
        elapsed_time = time.time() - start_time
        print(f'Epoch {epoch}, Train Loss: {avg_train_loss:.6f}, Val Loss: {avg_val_loss:.6f}, Time: {elapsed_time:.2f}s')

# 学習時間の計測終了
elapsed_time = time.time() - start_time
print(f"\nTotal training time: {elapsed_time:.2f} seconds")

# 最良のモデルをロード
model.load_state_dict(torch.load(early_stopping.path))
model.eval()

# テストデータでの評価
test_loss = 0
test_preds = []
test_targets = []
with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1).float())
        test_loss += loss.item()
        test_preds.append(out.cpu().numpy())
        test_targets.append(batch.y.cpu().numpy())

test_loss /= len(test_loader)
test_preds = np.concatenate(test_preds)
test_targets = np.concatenate(test_targets)

# 評価指標の計算
predicted_labels = (test_preds >= 0.5).astype(int)  # 開き隔ちは0.5
accuracy = accuracy_score(test_targets, predicted_labels)
precision = precision_score(test_targets, predicted_labels)
recall = recall_score(test_targets, predicted_labels)
f1 = f1_score(test_targets, predicted_labels)

print(f'\nTest Loss: {test_loss:.6f}, Accuracy: {accuracy:.6f}, Precision: {precision:.6f}, Recall: {recall:.6f}, F1 Score: {f1:.6f}')

# テスト損失をTensorBoardに記録
writer.add_scalar('Loss/test', test_loss, epoch)

# 損失をプロット
plt.figure(figsize=(12, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', color='blue')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', color='orange')
plt.yscale('log')  # 対数スケール
plt.xlabel('Epoch')
plt.ylabel('Loss (Log Scale)')
plt.title(f'Training and Validation Loss GATModel - ({timestamp})')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.savefig(f'/home/nishioka/GNN/Defect_12x12_data/GNNmodelgraphfig/loss_fig_GATModel_{timestamp}.png')
plt.show()

# モデルとハイパーパラメータをJSONに保存
model_params = {
    'model': 'GATModel',
    'hidden_channels': hidden_channels,
    'learning_rate': learning_rate,
    'batch_size': batch_size,
    'epochs': epoch,
    'weight_decay': weight_decay,
    'patience': patience
}
with open(f'/home/nishioka/GNN/Defect_12x12_data/GNNmodel/{type(model).__name__}_params_{timestamp}.json', 'w') as f:
    json.dump(model_params, f, indent=4)

# 損失とハイパーパラメータ情報をCSVに保存
loss_data = pd.DataFrame({
    'Epoch': range(1, len(train_losses) + 1),
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})
loss_data.to_csv(f'/home/nishioka/GNN/Defect_12x12_data/GNNmodelcsv/loss_data_{timestamp}.csv', index=False)

# テスト損失の保存
test_loss_data = pd.DataFrame({
    'Test Loss': [test_loss],
    'Accuracy': [accuracy],
    'Precision': [precision],
    'Recall': [recall],
    'F1 Score': [f1]
})
test_loss_data.to_csv(f'/home/nishioka/GNN/Defect_12x12_data/GNNmodelcsv/test_loss_{timestamp}.csv', index=False)

# モデルの保存（ファイル名にタイムスタンプを追加）
torch.save(model.state_dict(), f'/home/nishioka/GNN/Defect_12x12_data/GNNmodel/GATModel_final_{test_loss:.6f}_{timestamp}.pth')
torch.save(model.state_dict(), f'/home/nishioka/GNN/Defect_12x12_data/GNNmodelweights/GATModel_weights_{test_loss:.6f}_{timestamp}.pth')

# TensorBoardのWriterを閉じる
writer.close()

# 最終的なサマリーの表示
print("\nTraining Summary:")
print(f"Total Epochs Run: {epoch}")
if early_stopping.early_stop:
    print(f"Early stopping at epoch {epoch}")
else:
    print("Training completed without early stopping.")
print(f"Final Training Loss: {train_losses[-1]:.6f}")
print(f"Best Validation Loss: {early_stopping.val_loss_min:.6f}")
print(f"Test Loss: {test_loss:.6f}")
print(f"Accuracy: {accuracy:.6f}")
print(f"Precision: {precision:.6f}")
print(f"Recall: {recall:.6f}")
print(f"F1 Score: {f1:.6f}")
print(f"Total Training Time: {elapsed_time:.2f} seconds")
# Out:
# GPU is available: NVIDIA GeForce RTX 3090
#
# Defect-free data occurrences in train_pairs: 8 (expected: 8)
# Defect-free data occurrences in val_pairs: 1 (expected: 1)
# Defect-free data occurrences in test_pairs: 1 (expected: 1)
#
# All defect-free data pairs are correctly added.
#
# After sampling:
# Train pairs count (including defect-free): 150
# Validation pairs count (including defect-free): 20
# Test pairs count (including defect-free): 20
#
# Dataset Sizes:
# Training data size: 150 samples
# Validation data size: 20 samples
# Test data size: 20 samples
#
# --- Training Start ---
# Validation loss decreased (inf --> 0.215795). Saving model...
# Epoch 1, Train Loss: 0.517161, Val Loss: 0.215795, Time: 1.07s
# Validation loss decreased (0.215795 --> 0.183263). Saving model...
# Validation loss decreased (0.183263 --> 0.174787). Saving model...
# Validation loss decreased (0.174787 --> 0.172687). Saving model...
# Epoch 10, Train Loss: 0.169414, Val Loss: 0.172698, Time: 7.05s
# Validation loss decreased (0.172687 --> 0.171785). Saving model...
# Validation loss decreased (0.171785 --> 0.171481). Saving model...
# Validation loss decreased (0.171481 --> 0.171207). Saving model...
# Validation loss decreased (0.171207 --> 0.170804). Saving model...
# Validation loss decreased (0.170804 --> 0.170717). Saving model...
# Validation loss decreased (0.170717 --> 0.170548). Saving model...
# Validation loss decreased (0.170548 --> 0.170535). Saving model...
# Validation loss decreased (0.170535 --> 0.170374). Saving model...
# Validation loss decreased (0.170374 --> 0.170282). Saving model...
# Validation loss decreased (0.170282 --> 0.170176). Saving model...
# Validation loss decreased (0.170176 --> 0.170006). Saving model...
# Validation loss decreased (0.170006 --> 0.169711). Saving model...
# Validation loss decreased (0.169711 --> 0.169566). Saving model...
# Validation loss decreased (0.169566 --> 0.169562). Saving model...
# Validation loss decreased (0.169562 --> 0.169230). Saving model...
# Epoch 30, Train Loss: 0.166664, Val Loss: 0.169265, Time: 20.70s
# Validation loss decreased (0.169230 --> 0.169091). Saving model...
# Validation loss decreased (0.169091 --> 0.168963). Saving model...
# Validation loss decreased (0.168963 --> 0.168794). Saving model...
# Validation loss decreased (0.168794 --> 0.168633). Saving model...
# Validation loss decreased (0.168633 --> 0.168168). Saving model...
# Validation loss decreased (0.168168 --> 0.167813). Saving model...
# Validation loss decreased (0.167813 --> 0.167671). Saving model...
# Validation loss decreased (0.167671 --> 0.166962). Saving model...
# Epoch 50, Train Loss: 0.164665, Val Loss: 0.167128, Time: 34.03s
# Validation loss decreased (0.166962 --> 0.166867). Saving model...
# Validation loss decreased (0.166867 --> 0.166685). Saving model...
# Validation loss decreased (0.166685 --> 0.165978). Saving model...
# Validation loss decreased (0.165978 --> 0.165475). Saving model...
# Validation loss decreased (0.165475 --> 0.165310). Saving model...
# Validation loss decreased (0.165310 --> 0.165066). Saving model...
# Validation loss decreased (0.165066 --> 0.164726). Saving model...
# Validation loss decreased (0.164726 --> 0.163996). Saving model...
# Validation loss decreased (0.163996 --> 0.163899). Saving model...
# Validation loss decreased (0.163899 --> 0.163406). Saving model...
# Validation loss decreased (0.163406 --> 0.163160). Saving model...
# Validation loss decreased (0.163160 --> 0.162875). Saving model...
# Validation loss decreased (0.162875 --> 0.162845). Saving model...
# Validation loss decreased (0.162845 --> 0.162710). Saving model...
# Validation loss decreased (0.162710 --> 0.162644). Saving model...
# Validation loss decreased (0.162644 --> 0.162594). Saving model...
# Validation loss decreased (0.162594 --> 0.162411). Saving model...
# Epoch 100, Train Loss: 0.160538, Val Loss: 0.166851, Time: 67.25s
# Validation loss decreased (0.162411 --> 0.162305). Saving model...
# Validation loss decreased (0.162305 --> 0.161994). Saving model...
# Validation loss decreased (0.161994 --> 0.161984). Saving model...
# Validation loss decreased (0.161984 --> 0.161687). Saving model...
# Validation loss decreased (0.161687 --> 0.161540). Saving model...
# Validation loss decreased (0.161540 --> 0.161495). Saving model...
# Validation loss decreased (0.161495 --> 0.161035). Saving model...
# Validation loss decreased (0.161035 --> 0.160895). Saving model...
# Validation loss decreased (0.160895 --> 0.160825). Saving model...
# Epoch 150, Train Loss: 0.158159, Val Loss: 0.161230, Time: 100.29s
# Validation loss decreased (0.160825 --> 0.160731). Saving model...
# Validation loss decreased (0.160731 --> 0.160490). Saving model...
# Validation loss decreased (0.160490 --> 0.160288). Saving model...
# Validation loss decreased (0.160288 --> 0.160031). Saving model...
# Validation loss decreased (0.160031 --> 0.160022). Saving model...
# Epoch 200, Train Loss: 0.157677, Val Loss: 0.160582, Time: 132.99s
# Validation loss decreased (0.160022 --> 0.159928). Saving model...
# Validation loss decreased (0.159928 --> 0.159631). Saving model...
# Validation loss decreased (0.159631 --> 0.159456). Saving model...
# Validation loss decreased (0.159456 --> 0.159403). Saving model...
# Epoch 250, Train Loss: 0.157853, Val Loss: 0.160115, Time: 165.64s
# Validation loss decreased (0.159403 --> 0.159144). Saving model...
# Validation loss decreased (0.159144 --> 0.159079). Saving model...
# Validation loss decreased (0.159079 --> 0.158938). Saving model...
# Epoch 300, Train Loss: 0.156121, Val Loss: 0.158938, Time: 198.24s
# Validation loss decreased (0.158938 --> 0.158839). Saving model...
# Validation loss decreased (0.158839 --> 0.158697). Saving model...
# Epoch 350, Train Loss: 0.156327, Val Loss: 0.159737, Time: 230.80s
# Validation loss decreased (0.158697 --> 0.158426). Saving model...
# Validation loss decreased (0.158426 --> 0.158175). Saving model...
# Validation loss decreased (0.158175 --> 0.157978). Saving model...
# Epoch 400, Train Loss: 0.155320, Val Loss: 0.158550, Time: 263.40s
# Validation loss decreased (0.157978 --> 0.157960). Saving model...
# Epoch 450, Train Loss: 0.157245, Val Loss: 0.159589, Time: 295.90s
# Validation loss decreased (0.157960 --> 0.157842). Saving model...
# Validation loss decreased (0.157842 --> 0.157637). Saving model...
# Validation loss decreased (0.157637 --> 0.157447). Saving model...
# Validation loss decreased (0.157447 --> 0.157186). Saving model...
# Validation loss decreased (0.157186 --> 0.156938). Saving model...
# Epoch 500, Train Loss: 0.155846, Val Loss: 0.158156, Time: 328.57s
# Validation loss decreased (0.156938 --> 0.156893). Saving model...
# Validation loss decreased (0.156893 --> 0.156865). Saving model...
# Validation loss decreased (0.156865 --> 0.156716). Saving model...
# Epoch 550, Train Loss: 0.156800, Val Loss: 0.159341, Time: 361.14s
# Validation loss decreased (0.156716 --> 0.156492). Saving model...
# Validation loss decreased (0.156492 --> 0.156378). Saving model...
# Epoch 600, Train Loss: 0.154158, Val Loss: 0.160206, Time: 393.65s
# Validation loss decreased (0.156378 --> 0.156271). Saving model...
# Validation loss decreased (0.156271 --> 0.156052). Saving model...
# Validation loss decreased (0.156052 --> 0.155981). Saving model...
# Epoch 650, Train Loss: 0.153093, Val Loss: 0.156117, Time: 426.18s
# Validation loss decreased (0.155981 --> 0.155717). Saving model...
# Validation loss decreased (0.155717 --> 0.155707). Saving model...
# Validation loss decreased (0.155707 --> 0.155406). Saving model...
# Validation loss decreased (0.155406 --> 0.155365). Saving model...
# Validation loss decreased (0.155365 --> 0.155301). Saving model...
# Validation loss decreased (0.155301 --> 0.154832). Saving model...
# Validation loss decreased (0.154832 --> 0.154622). Saving model...
# Epoch 700, Train Loss: 0.152446, Val Loss: 0.155661, Time: 458.86s
# Validation loss decreased (0.154622 --> 0.154461). Saving model...
# Validation loss decreased (0.154461 --> 0.154209). Saving model...
# Validation loss decreased (0.154209 --> 0.154002). Saving model...
# Validation loss decreased (0.154002 --> 0.153460). Saving model...
# Validation loss decreased (0.153460 --> 0.153324). Saving model...
# Epoch 750, Train Loss: 0.149889, Val Loss: 0.154189, Time: 491.46s
# Validation loss decreased (0.153324 --> 0.153105). Saving model...
# Validation loss decreased (0.153105 --> 0.152718). Saving model...
# Validation loss decreased (0.152718 --> 0.152606). Saving model...
# Validation loss decreased (0.152606 --> 0.152524). Saving model...
# Validation loss decreased (0.152524 --> 0.152314). Saving model...
# Epoch 800, Train Loss: 0.150567, Val Loss: 0.153492, Time: 524.04s
# Validation loss decreased (0.152314 --> 0.152206). Saving model...
# Validation loss decreased (0.152206 --> 0.152195). Saving model...
# Validation loss decreased (0.152195 --> 0.151716). Saving model...
# Validation loss decreased (0.151716 --> 0.151335). Saving model...
# Epoch 850, Train Loss: 0.149364, Val Loss: 0.154219, Time: 556.57s
# Validation loss decreased (0.151335 --> 0.150488). Saving model...
# Validation loss decreased (0.150488 --> 0.150386). Saving model...
# Validation loss decreased (0.150386 --> 0.149886). Saving model...
# Validation loss decreased (0.149886 --> 0.149839). Saving model...
# Validation loss decreased (0.149839 --> 0.149737). Saving model...
# Epoch 900, Train Loss: 0.146874, Val Loss: 0.151308, Time: 589.17s
# Validation loss decreased (0.149737 --> 0.149340). Saving model...
# Validation loss decreased (0.149340 --> 0.149271). Saving model...
# Validation loss decreased (0.149271 --> 0.148983). Saving model...
# Validation loss decreased (0.148983 --> 0.148425). Saving model...
# Validation loss decreased (0.148425 --> 0.148359). Saving model...
# Validation loss decreased (0.148359 --> 0.147328). Saving model...
# Epoch 950, Train Loss: 0.147242, Val Loss: 0.147328, Time: 621.79s
# Epoch 1000, Train Loss: 0.149435, Val Loss: 0.149169, Time: 654.17s
# Validation loss decreased (0.147328 --> 0.147310). Saving model...
# Validation loss decreased (0.147310 --> 0.147217). Saving model...
# Epoch 1050, Train Loss: 0.144685, Val Loss: 0.148838, Time: 686.63s
# Validation loss decreased (0.147217 --> 0.147210). Saving model...
# Validation loss decreased (0.147210 --> 0.147110). Saving model...
# Epoch 1100, Train Loss: 0.146945, Val Loss: 0.149835, Time: 719.09s
# Validation loss decreased (0.147110 --> 0.147045). Saving model...
# Validation loss decreased (0.147045 --> 0.146639). Saving model...
# Validation loss decreased (0.146639 --> 0.146517). Saving model...
# Validation loss decreased (0.146517 --> 0.146399). Saving model...
# Epoch 1150, Train Loss: 0.143999, Val Loss: 0.148730, Time: 751.65s
# Validation loss decreased (0.146399 --> 0.146131). Saving model...
# Validation loss decreased (0.146131 --> 0.145763). Saving model...
# Epoch 1200, Train Loss: 0.147610, Val Loss: 0.147830, Time: 784.13s
# Validation loss decreased (0.145763 --> 0.145293). Saving model...
# Validation loss decreased (0.145293 --> 0.145198). Saving model...
# Epoch 1250, Train Loss: 0.142144, Val Loss: 0.145665, Time: 816.59s
# Validation loss decreased (0.145198 --> 0.144972). Saving model...
# Epoch 1300, Train Loss: 0.143304, Val Loss: 0.147104, Time: 849.02s
# Validation loss decreased (0.144972 --> 0.144648). Saving model...
# Validation loss decreased (0.144648 --> 0.144616). Saving model...
# Epoch 1350, Train Loss: 0.142116, Val Loss: 0.146613, Time: 881.52s
# Epoch 1400, Train Loss: 0.142832, Val Loss: 0.146293, Time: 913.90s
# Validation loss decreased (0.144616 --> 0.144259). Saving model...
# Validation loss decreased (0.144259 --> 0.143852). Saving model...
# Epoch 1450, Train Loss: 0.142612, Val Loss: 0.145925, Time: 946.36s
# Epoch 1500, Train Loss: 0.142702, Val Loss: 0.144885, Time: 978.76s
# Validation loss decreased (0.143852 --> 0.143836). Saving model...
# Validation loss decreased (0.143836 --> 0.143629). Saving model...
# Validation loss decreased (0.143629 --> 0.143241). Saving model...
# Epoch 1550, Train Loss: 0.142357, Val Loss: 0.146510, Time: 1011.28s
# Epoch 1600, Train Loss: 0.141622, Val Loss: 0.144559, Time: 1043.66s
# Early stopping at epoch 1625
#
# Total training time: 1059.85 seconds
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 363
#     361 # 評価指標の計算
#     362 predicted_labels = (test_preds >= 0.5).astype(int)  # 開き隔ちは0.5
# --> 363 accuracy = accuracy_score(test_targets, predicted_labels)
#     364 precision = precision_score(test_targets, predicted_labels)
#     365 recall = recall_score(test_targets, predicted_labels)
#
# File ~/miniconda3/envs/interstage_gnn_first/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/miniconda3/envs/interstage_gnn_first/lib/python3.12/site-packages/sklearn/metrics/_classification.py:231, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     229 xp, _, device = get_namespace_and_device(y_true, y_pred, sample_weight)
#     230 # Compute accuracy for each possible representation
# --> 231 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     232 check_consistent_length(y_true, y_pred, sample_weight)
#     233 if y_type.startswith("multilabel"):
#
# File ~/miniconda3/envs/interstage_gnn_first/lib/python3.12/site-packages/sklearn/metrics/_classification.py:112, in _check_targets(y_true, y_pred)
#     109     y_type = {"multiclass"}
#     111 if len(y_type) > 1:
# --> 112     raise ValueError(
#     113         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#     114             type_true, type_pred
#     115         )
#     116     )
#     118 # We can't have more than one value on y_type => The set is no more needed
#     119 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of continuous and binary targets
