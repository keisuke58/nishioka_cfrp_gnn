# %%
import torch

if torch.cuda.is_available():
    print("GPU is available")
    print(f"Using device: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available, using CPU")

# %%
import os
import time
import json
import numpy as np
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader  # 修正
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from torch.utils.tensorboard import SummaryWriter

if torch.cuda.is_available():
    print("GPU is available")
    print(f"Using device: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available, using CPU")
    
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")


# データフォルダ
standardized_data_folder = "/home/nishioka/GNN/Defect_4x4_Standardized1"
label_data_folder = "/home/nishioka/GNN/DefectLabels_4x4_test1"

# 座標データのロード
x_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/x_2layer.npy")[:3654]
y_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/y_2layer.npy")[:3654]
z_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/z_2layer.npy")[:3654]

# エッジ情報を読み込む
edges = np.load("/home/nishioka/GNN/BasicdataforGNN/edges_2layer.npy")
edge_index = torch.tensor(edges.T, dtype=torch.long).to(device)

# データとラベルファイルを対応付け
data_files = [f for f in os.listdir(standardized_data_folder) if f.startswith("Standardized1_Defect4x4_ELNOD")]
label_files = [f for f in os.listdir(label_data_folder) if f.startswith("DefectLabel_L")]

# 欠陥なしのファイルを追加
data_files.append("0Standardized1_nodefect_4x4_ElNOD.npy")
label_files.append("0DefectLabel_nodefect1.npy")

# データとラベルのペアを取得する関数
def extract_layer_block(file_name):
    if file_name.startswith("0"):
        return (0, 0)  # 欠陥なしデータの場合
    try:
        layer_block_str = file_name.split("_")[-1].replace(".npy", "")
        layer_str = layer_block_str.split("L")[1].split("B")[0]
        block_str = layer_block_str.split("B")[1]
        layer = int(layer_str)
        block = int(block_str)
        return (layer, block)
    except (ValueError, IndexError):
        print(f"無効なファイル名の形式: {file_name}")
        return None

# データとラベルのペアを作成
data_label_pairs = {}
for data_file in data_files:
    layer_block = extract_layer_block(data_file)
    if layer_block:
        data_label_pairs[layer_block] = {"data": data_file}

for label_file in label_files:
    layer_block = extract_layer_block(label_file)
    if layer_block and layer_block in data_label_pairs:
        data_label_pairs[layer_block]["label"] = label_file

# 有効なペアのみ取得
valid_pairs = [(v["data"], v["label"]) for k, v in data_label_pairs.items() if "label" in v]

# ランダムにサンプリング
num_samples = 1296
random_indices = np.random.choice(len(valid_pairs), num_samples, replace=False)

# サンプルをトレーニングデータとして取得
train_pairs = [valid_pairs[i] for i in random_indices]

# 残りのデータを取得
remaining_pairs = [valid_pairs[i] for i in range(len(valid_pairs)) if i not in random_indices]

# 残りのデータを1:1でバリデーションとテストに分割
val_pairs, test_pairs = train_test_split(remaining_pairs, test_size=0.5, random_state=42)

# 検証データとテストデータを適切に分けて格納
train_data = [pair[0] for pair in train_pairs]
train_labels = [pair[1] for pair in train_pairs]

val_data = [pair[0] for pair in val_pairs]
val_labels = [pair[1] for pair in val_pairs]

test_data = [pair[0] for pair in test_pairs]
test_labels = [pair[1] for pair in test_pairs]

# 結果を表示
print(f"Training data size: {len(train_data)}")
print(f"Validation data size: {len(val_data)}")
print(f"Test data size: {len(test_data)}")

# データ準備の関数
def prepare_data(pairs):
    sampled_data = []
    sampled_labels = []
    
    for data_file, label_file in pairs:
        data_file_path = os.path.join(standardized_data_folder, data_file)
        label_file_path = os.path.join(label_data_folder, label_file)

        # データとラベルを読み込む
        values = np.load(data_file_path)[:3654]
        label = np.load(label_file_path)[:3654]
        
        # 座標データと応力データを結合してノード特徴量を作成
        node_features = np.vstack((x_coords, y_coords, z_coords, values)).T
        sampled_data.append(node_features)
        sampled_labels.append(label)
    
    # データを結合しテンソルに変換
    sampled_data = np.stack(sampled_data)
    sampled_labels = np.hstack(sampled_labels)

    x = torch.tensor(sampled_data.reshape(-1, 4), dtype=torch.float).to(device)
    y = torch.tensor(sampled_labels, dtype=torch.float).to(device)

    return x, y

# 各データセットを準備
train_x, train_y = prepare_data(train_pairs)
val_x, val_y = prepare_data(val_pairs)
test_x, test_y = prepare_data(test_pairs)

# Dataオブジェクトにまとめる
train_data = Data(x=train_x, edge_index=edge_index, y=train_y)
val_data = Data(x=val_x, edge_index=edge_index, y=val_y)
test_data = Data(x=test_x, edge_index=edge_index, y=test_y)

# 実際のデータ数を表示する関数
def print_data_info(data, name):
    print(f"{name} Data size: {data.x.size(0)}")  # xの最初の次元（ノード数）でデータ数を取得
    print(f"{name} Edge size: {data.edge_index.size(1)}")  # エッジ数
    print(f"{name} Label size: {data.y.size(0)}")  # ラベルの数

# 各データセットの情報を表示
print_data_info(train_data, "Training")
print_data_info(val_data, "Validation")
print_data_info(test_data, "Test")

# 欠陥なしデータがトレーニングデータに含まれているか確認
no_defect_in_train = ("0Standardized1_nodefect_4x4_ElNOD.npy", "0DefectLabel_nodefect1.npy") in train_pairs

if no_defect_in_train:
    print("Defect-free data is included in the training data.")
else:
    print("欠陥なしデータがトレーニングデータに含まれていません。")

# 結果を確認
print(f"Training data: {train_data}")
print(f"Validation data: {val_data}")
print(f"Test data: {test_data}")

# ペアが正しく対応しているか確認
print("\n--- Training ---")
for data_file, label_file in train_pairs[:2]:  # トレーニングデータの先頭3個を表示
    print(f"data: {data_file}, label: {label_file}")

print("\n--- Validation ---")
for data_file, label_file in val_pairs[:2]:  # 検証データの先頭3個を表示
    print(f"data: {data_file}, label: {label_file}")

print("\n--- Test ---")
for data_file, label_file in test_pairs[:2]:  # テストデータの先頭3個を表示
    print(f"data: {data_file}, label: {label_file}")

# Xavier初期化関数
def init_weights(m):
    if isinstance(m, torch.nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight)
    elif isinstance(m, GCNConv):
        torch.nn.init.xavier_uniform_(m.lin.weight)

# GCNモデルの定義
class GCNModel(torch.nn.Module):
    def __init__(self, hidden_channels=32):
        super(GCNModel, self).__init__()
        self.conv1 = GCNConv(4, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels*2)
        self.conv3 = GCNConv(hidden_channels*2, hidden_channels)
        self.fc_defect = torch.nn.Linear(hidden_channels, 1)  # 回帰タスク用に出力1次元

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv3(x, edge_index))
        return self.fc_defect(x)

# ハイパーパラメータ設定
hidden_channels = 32
learning_rate = 0.0001
batch_size = 32
epochs = 150
weight_decay = 1e-4
patience = 20  # Early Stopping用


# モデル、損失関数、オプティマイザの定義
model = GCNModel(hidden_channels=hidden_channels).to(device)
model.apply(init_weights)  # Xavier初期化
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
loss_fn = torch.nn.MSELoss()

# TensorBoardの初期化
writer = SummaryWriter(log_dir=f'/home/nishioka/GNN/GNNlogs/{timestamp}')

# Early Stopping用の変数
best_val_loss = float('inf')
counter = 0

# 学習時間の計測
start_time = time.time()

# データをサンプルごとに分割
train_data_list = []
val_data_list = []
test_data_list = []

# サンプル単位でデータをDataLoaderに渡す
num_train_samples = train_x.shape[0] // 3654  # サンプル数の計算
num_val_samples = val_x.shape[0] // 3654
num_test_samples = test_x.shape[0] // 3654

for i in range(num_train_samples):
    train_data_list.append(Data(x=train_x[i*3654:(i+1)*3654], edge_index=edge_index, y=train_y[i*3654:(i+1)*3654]))

for i in range(num_val_samples):
    val_data_list.append(Data(x=val_x[i*3654:(i+1)*3654], edge_index=edge_index, y=val_y[i*3654:(i+1)*3654]))

for i in range(num_test_samples):
    test_data_list.append(Data(x=test_x[i*3654:(i+1)*3654], edge_index=edge_index, y=test_y[i*3654:(i+1)*3654]))

# データローダーの作成
train_loader = DataLoader(train_data_list, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data_list, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data_list, batch_size=32, shuffle=False)

# EarlyStopping クラス定義
class EarlyStopping:
    """Early stopping utility to stop training when validation loss doesn't improve."""
    def __init__(self, patience=patience, verbose=False, delta=0, path='/home/nishioka/GNN/checkpoint1.pt', trace_func=print):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss
        
# EarlyStoppingクラスのインスタンス作成
early_stopping = EarlyStopping(patience=10, verbose=True, path=f'/home/nishioka/GNN/GNNmodel/gcn_model_best_{timestamp}.pth')

train_losses = []
val_losses = []
test_losses = []
start_time = time.time()

# 学習ループの開始
for epoch in range(1, epochs + 1):
    model.train()
    total_loss = 0

    for batch in train_loader:
        batch.x = batch.x.to(device)
        batch.y = batch.y.to(device)
        batch.edge_index = batch.edge_index.to(device)
        optimizer.zero_grad()
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1).float().to(device))  # yをfloat型に変換してGPUに移動
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    train_losses.append(total_loss / len(train_loader))

    # 検証ステップ
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in val_loader:
            batch.x = batch.x.to(device)
            batch.y = batch.y.to(device)
            batch.edge_index = batch.edge_index.to(device)
            out = model(batch)
            loss = loss_fn(out, batch.y.view(-1, 1).float().to(device))
            val_loss += loss.item()

    val_losses.append(val_loss / len(val_loader))

    # EarlyStoppingに現在のバリデーション損失とモデルを渡す
    early_stopping(val_loss / len(val_loader), model)

    # EarlyStoppingがTrueなら訓練を終了
    if early_stopping.early_stop:
        print(f"Early stopping at epoch {epoch}")
        break

    # 10エポックごとに結果を出力
    if epoch % 10 == 0:
        elapsed_time = time.time() - start_time
        print(f'Epoch {epoch}, Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, Time: {elapsed_time:.2f}s')

# # 学習と検証
# train_losses = []
# val_losses = []
# test_losses = []
# start_time = time.time()

# テストデータでの評価
test_loss = 0
test_preds = []
test_targets = []
with torch.no_grad():
    for batch in test_loader:
        batch.x = batch.x.to(device)
        batch.y = batch.y.to(device)
        batch.edge_index = batch.edge_index.to(device)
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1))
        test_loss += loss.item()
        test_preds.append(out.cpu().numpy())
        test_targets.append(batch.y.cpu().numpy())

test_loss /= len(test_loader)
test_preds = np.concatenate(test_preds)
test_targets = np.concatenate(test_targets)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(test_targets, test_preds))

# MAE (Mean Absolute Error)
mae = mean_absolute_error(test_targets, test_preds)

# R2 Score
r2 = r2_score(test_targets, test_preds)

print(f'Test Loss: {test_loss:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R2 Score: {r2:.4f}')

# TensorBoardに損失を記録
writer.add_scalar('Loss/train', train_losses[-1], epoch)
writer.add_scalar('Loss/val', val_losses[-1], epoch)
        
# 学習時間の計測終了
elapsed_time = time.time() - start_time
print(f"Total training time: {elapsed_time:.2f} seconds")

# モデル、学習結果の保存
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodel/gcn_model_final_{timestamp}.pth')

# 学習時間をファイルに保存
with open(f'/home/nishioka/GNN/GNNmodelcsv/training_time_{timestamp}.txt', 'w') as f:
    f.write(f"Total training time: {elapsed_time:.2f} seconds\n")

# 損失とその他の指標をCSVに保存
loss_data = pd.DataFrame({
    'Epoch': range(1, len(train_losses) + 1),
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})
loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/loss_data_{timestamp}.csv', index=False)


# 損失をプロット
plt.figure(figsize=(12, 6))
plt.plot(range(1, epochs + 1), train_losses, label='Training Loss', color='blue')
plt.plot(range(1, epochs + 1), val_losses, label='Validation Loss', color='orange')
plt.yscale('log')  # 対数スケール
plt.xlabel('Epoch')
plt.ylabel('Loss (Log Scale)')
plt.title('Training and Validation Loss {timestamp} (Log Scale)')
plt.legend()
plt.grid(True, which="both", ls="--")

# テキストボックスをグラフに追加
hyperparams_text = f'Hidden Channels: {hidden_channels}\nLearning Rate: {learning_rate}\nBatch Size: {batch_size}\nEpochs: {epochs}\nWeight Decay: {weight_decay}\nPatience: {patience}'
plt.gcf().text(0.15, 0.75, hyperparams_text, fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

plt.grid(True, which="both", ls="--")
plt.savefig(f'/home/nishioka/GNN/GNNmodelgraphfig/loss_plot_{timestamp}.png')
plt.show()


# モデルとハイパーパラメータをJSONに保存する例
model_params = {
    'hidden_channels': hidden_channels,
    'learning_rate': learning_rate,
    'batch_size': batch_size,
    'epochs': epochs,
    'weight_decay': weight_decay,
    'patience': patience
}
with open(f'/home/nishioka/GNN/GNNmodel/gcn_model_params_{timestamp}.json', 'w') as f:
    json.dump(model_params, f, indent=4)

# プロットにハイパーパラメータ情報を追加
table_data = [
    ["Learning Rate", learning_rate],
    ["Batch Size", batch_size],
    ["Epochs", epochs],
    ["Weight Decay", weight_decay],
    ["Training Samples", num_train_samples],
    ["Validation Samples", num_val_samples],
    ["Test Samples", num_test_samples]
]

plt.table(cellText=table_data, colLabels=["Parameter", "Value"], cellLoc="center", loc="bottom", bbox=[0, -0.5, 1, 0.3])
plt.subplots_adjust(left=0.1, bottom=0.4)  # 表を表示するためのスペース確保
plt.savefig(f'/home/nishioka/GNN/GNNmodelgraphfig/loss_plot_{test_loss:.4f}_{timestamp}.png')  # 画像の保存
plt.show()

# 損失とハイパーパラメータ情報をCSVに保存
loss_data = pd.DataFrame({
    'Epoch': range(1, epochs + 1),
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})
loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/loss_data_{test_loss:.4f}_{timestamp}.csv', index=False)

# ハイパーパラメータのCSV
hyperparameter_data = pd.DataFrame(table_data, columns=["Parameter", "Value"])
hyperparameter_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/hyperparameters_{test_loss:.4f}_{timestamp}.csv', index=False)

# 結果を保存
test_loss_data = pd.DataFrame({
    'Test Loss': [test_loss],
    'RMSE': [rmse],
    'MAE': [mae],
    'R2 Score': [r2]
})
test_loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/test_loss_{test_loss:.4f}_{timestamp}.csv', index=False)

# ファイル名にタイムスタンプを追加

test_loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/test_loss_{test_loss:.4f}_{timestamp}.csv', index=False)

# モデルの保存（ファイル名にタイムスタンプを追加）
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodel/gcn_model_{test_loss:.4f}_{timestamp}.pth')
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodelweights/gcn_model_weights_{test_loss:.4f}_{timestamp}.pth')

# TensorBoardのWriterを閉じる
writer.close()

# プログラムが終了したら何をすべきか
print("すべての学習プロセスが完了しました。次のステップ:")
print("- モデルのパフォーマンスをテストデータで確認")
print("- 保存したモデルやハイパーパラメータのレビュー")
print("- 必要であればモデルの微調整（例: 新しいハイパーパラメータのテスト）")
# Out:
# GPU is available
# Using device: NVIDIA GeForce RTX 3090
# Training data size: 1296
# Validation data size: 162
# Test data size: 163
# Training Data size: 4735584
# Training Edge size: 7124
# Training Label size: 4735584
# Validation Data size: 591948
# Validation Edge size: 7124
# Validation Label size: 591948
# Test Data size: 595602
# Test Edge size: 7124
# Test Label size: 595602
# Defect-free data is included in the training data.
# Training data: Data(x=[4735584, 4], edge_index=[2, 7124], y=[4735584])
# Validation data: Data(x=[591948, 4], edge_index=[2, 7124], y=[591948])
# Test data: Data(x=[595602, 4], edge_index=[2, 7124], y=[595602])
#
# --- Training ---
# data: Standardized1_Defect4x4_ELNOD_L18B76.npy, label: DefectLabel_L18B76.npy
# data: Standardized1_Defect4x4_ELNOD_L19B37.npy, label: DefectLabel_L19B37.npy
#
# --- Validation ---
# data: Standardized1_Defect4x4_ELNOD_L19B89.npy, label: DefectLabel_L19B89.npy
# data: Standardized1_Defect4x4_ELNOD_L8B43.npy, label: DefectLabel_L8B43.npy
#
# --- Test ---
# data: Standardized1_Defect4x4_ELNOD_L12B79.npy, label: DefectLabel_L12B79.npy
# data: Standardized1_Defect4x4_ELNOD_L15B42.npy, label: DefectLabel_L15B42.npy
# Validation loss decreased (inf --> 697.944387). Saving model...
# Validation loss decreased (697.944387 --> 151.095929). Saving model...
# Validation loss decreased (151.095929 --> 76.088315). Saving model...
# Validation loss decreased (76.088315 --> 49.567327). Saving model...
# Validation loss decreased (49.567327 --> 29.092322). Saving model...
# Validation loss decreased (29.092322 --> 23.778443). Saving model...
# Validation loss decreased (23.778443 --> 20.745878). Saving model...
# Validation loss decreased (20.745878 --> 18.433135). Saving model...
# Validation loss decreased (18.433135 --> 16.511519). Saving model...
# Validation loss decreased (16.511519 --> 14.852180). Saving model...
# Epoch 10, Train Loss: 15.6820, Val Loss: 14.8522, Time: 18.74s
# Validation loss decreased (14.852180 --> 13.373345). Saving model...
# Validation loss decreased (13.373345 --> 12.049551). Saving model...
# Validation loss decreased (12.049551 --> 10.850923). Saving model...
# Validation loss decreased (10.850923 --> 9.670083). Saving model...
# Validation loss decreased (9.670083 --> 8.642925). Saving model...
# Validation loss decreased (8.642925 --> 7.771472). Saving model...
# Validation loss decreased (7.771472 --> 7.011475). Saving model...
# Validation loss decreased (7.011475 --> 6.336079). Saving model...
# Validation loss decreased (6.336079 --> 5.711359). Saving model...
# Validation loss decreased (5.711359 --> 5.130974). Saving model...
# Epoch 20, Train Loss: 5.4218, Val Loss: 5.1310, Time: 37.79s
# Validation loss decreased (5.130974 --> 4.531827). Saving model...
# Validation loss decreased (4.531827 --> 3.917563). Saving model...
# Validation loss decreased (3.917563 --> 3.318647). Saving model...
# Validation loss decreased (3.318647 --> 2.821417). Saving model...
# Validation loss decreased (2.821417 --> 2.436777). Saving model...
# Validation loss decreased (2.436777 --> 2.096775). Saving model...
# Validation loss decreased (2.096775 --> 1.757152). Saving model...
# Validation loss decreased (1.757152 --> 1.434761). Saving model...
# Validation loss decreased (1.434761 --> 1.202510). Saving model...
# Validation loss decreased (1.202510 --> 1.036496). Saving model...
# Epoch 30, Train Loss: 1.1163, Val Loss: 1.0365, Time: 56.55s
# Validation loss decreased (1.036496 --> 0.913557). Saving model...
# Validation loss decreased (0.913557 --> 0.820833). Saving model...
# Validation loss decreased (0.820833 --> 0.750969). Saving model...
# Validation loss decreased (0.750969 --> 0.697760). Saving model...
# Validation loss decreased (0.697760 --> 0.655978). Saving model...
# Validation loss decreased (0.655978 --> 0.622384). Saving model...
# Validation loss decreased (0.622384 --> 0.594914). Saving model...
# Validation loss decreased (0.594914 --> 0.572085). Saving model...
# Validation loss decreased (0.572085 --> 0.552818). Saving model...
# Validation loss decreased (0.552818 --> 0.536056). Saving model...
# Epoch 40, Train Loss: 0.5443, Val Loss: 0.5361, Time: 75.65s
# Validation loss decreased (0.536056 --> 0.521307). Saving model...
# Validation loss decreased (0.521307 --> 0.507954). Saving model...
# Validation loss decreased (0.507954 --> 0.495882). Saving model...
# Validation loss decreased (0.495882 --> 0.484665). Saving model...
# Validation loss decreased (0.484665 --> 0.474201). Saving model...
# Validation loss decreased (0.474201 --> 0.463363). Saving model...
# Validation loss decreased (0.463363 --> 0.452936). Saving model...
# Validation loss decreased (0.452936 --> 0.443574). Saving model...
# Validation loss decreased (0.443574 --> 0.434074). Saving model...
# Validation loss decreased (0.434074 --> 0.424452). Saving model...
# Epoch 50, Train Loss: 0.4295, Val Loss: 0.4245, Time: 94.57s
# Validation loss decreased (0.424452 --> 0.412702). Saving model...
# Validation loss decreased (0.412702 --> 0.389100). Saving model...
# Validation loss decreased (0.389100 --> 0.365938). Saving model...
# Validation loss decreased (0.365938 --> 0.347347). Saving model...
# Validation loss decreased (0.347347 --> 0.331952). Saving model...
# Validation loss decreased (0.331952 --> 0.314812). Saving model...
# Validation loss decreased (0.314812 --> 0.301264). Saving model...
# Validation loss decreased (0.301264 --> 0.290313). Saving model...
# Validation loss decreased (0.290313 --> 0.280338). Saving model...
# Validation loss decreased (0.280338 --> 0.270729). Saving model...
# Epoch 60, Train Loss: 0.2760, Val Loss: 0.2707, Time: 113.41s
# Validation loss decreased (0.270729 --> 0.262297). Saving model...
# Validation loss decreased (0.262297 --> 0.252672). Saving model...
# Validation loss decreased (0.252672 --> 0.244532). Saving model...
# Validation loss decreased (0.244532 --> 0.237266). Saving model...
# Validation loss decreased (0.237266 --> 0.231192). Saving model...
# Validation loss decreased (0.231192 --> 0.225885). Saving model...
# Validation loss decreased (0.225885 --> 0.221038). Saving model...
# Validation loss decreased (0.221038 --> 0.216620). Saving model...
# Validation loss decreased (0.216620 --> 0.212297). Saving model...
# Validation loss decreased (0.212297 --> 0.208690). Saving model...
# Epoch 70, Train Loss: 0.2104, Val Loss: 0.2087, Time: 131.75s
# Validation loss decreased (0.208690 --> 0.204602). Saving model...
# Validation loss decreased (0.204602 --> 0.201136). Saving model...
# Validation loss decreased (0.201136 --> 0.197987). Saving model...
# Validation loss decreased (0.197987 --> 0.194767). Saving model...
# Validation loss decreased (0.194767 --> 0.191937). Saving model...
# Validation loss decreased (0.191937 --> 0.189072). Saving model...
# Validation loss decreased (0.189072 --> 0.186606). Saving model...
# Validation loss decreased (0.186606 --> 0.183698). Saving model...
# Validation loss decreased (0.183698 --> 0.181155). Saving model...
# Validation loss decreased (0.181155 --> 0.178591). Saving model...
# Epoch 80, Train Loss: 0.1799, Val Loss: 0.1786, Time: 149.94s
# Validation loss decreased (0.178591 --> 0.176027). Saving model...
# Validation loss decreased (0.176027 --> 0.173228). Saving model...
# Validation loss decreased (0.173228 --> 0.170608). Saving model...
# Validation loss decreased (0.170608 --> 0.167647). Saving model...
# Validation loss decreased (0.167647 --> 0.164911). Saving model...
# Validation loss decreased (0.164911 --> 0.161709). Saving model...
# Validation loss decreased (0.161709 --> 0.158568). Saving model...
# Validation loss decreased (0.158568 --> 0.155191). Saving model...
# Validation loss decreased (0.155191 --> 0.152623). Saving model...
# Validation loss decreased (0.152623 --> 0.150080). Saving model...
# Epoch 90, Train Loss: 0.1510, Val Loss: 0.1501, Time: 167.34s
# Validation loss decreased (0.150080 --> 0.147027). Saving model...
# Validation loss decreased (0.147027 --> 0.143542). Saving model...
# Validation loss decreased (0.143542 --> 0.139309). Saving model...
# Validation loss decreased (0.139309 --> 0.136430). Saving model...
# Validation loss decreased (0.136430 --> 0.133465). Saving model...
# Validation loss decreased (0.133465 --> 0.131353). Saving model...
# Validation loss decreased (0.131353 --> 0.128400). Saving model...
# Validation loss decreased (0.128400 --> 0.127732). Saving model...
# Validation loss decreased (0.127732 --> 0.123602). Saving model...
# Validation loss decreased (0.123602 --> 0.121541). Saving model...
# Epoch 100, Train Loss: 0.1221, Val Loss: 0.1215, Time: 185.90s
# Validation loss decreased (0.121541 --> 0.119098). Saving model...
# Validation loss decreased (0.119098 --> 0.116498). Saving model...
# Validation loss decreased (0.116498 --> 0.114172). Saving model...
# Validation loss decreased (0.114172 --> 0.111998). Saving model...
# Validation loss decreased (0.111998 --> 0.109403). Saving model...
# Validation loss decreased (0.109403 --> 0.107507). Saving model...
# Validation loss decreased (0.107507 --> 0.104480). Saving model...
# Validation loss decreased (0.104480 --> 0.102031). Saving model...
# Validation loss decreased (0.102031 --> 0.099486). Saving model...
# Validation loss decreased (0.099486 --> 0.096937). Saving model...
# Epoch 110, Train Loss: 0.0982, Val Loss: 0.0969, Time: 204.44s
# Validation loss decreased (0.096937 --> 0.094568). Saving model...
# Validation loss decreased (0.094568 --> 0.091790). Saving model...
# Validation loss decreased (0.091790 --> 0.089131). Saving model...
# Validation loss decreased (0.089131 --> 0.086744). Saving model...
# Validation loss decreased (0.086744 --> 0.084926). Saving model...
# Validation loss decreased (0.084926 --> 0.082150). Saving model...
# Validation loss decreased (0.082150 --> 0.079508). Saving model...
# Validation loss decreased (0.079508 --> 0.077216). Saving model...
# Validation loss decreased (0.077216 --> 0.074766). Saving model...
# Validation loss decreased (0.074766 --> 0.073358). Saving model...
# Epoch 120, Train Loss: 0.0737, Val Loss: 0.0734, Time: 223.32s
# Validation loss decreased (0.073358 --> 0.070357). Saving model...
# Validation loss decreased (0.070357 --> 0.068885). Saving model...
# Validation loss decreased (0.068885 --> 0.065805). Saving model...
# Validation loss decreased (0.065805 --> 0.064400). Saving model...
# Validation loss decreased (0.064400 --> 0.062063). Saving model...
# Validation loss decreased (0.062063 --> 0.060522). Saving model...
# Validation loss decreased (0.060522 --> 0.058767). Saving model...
# Validation loss decreased (0.058767 --> 0.058164). Saving model...
# Validation loss decreased (0.058164 --> 0.056665). Saving model...
# Validation loss decreased (0.056665 --> 0.054808). Saving model...
# Epoch 130, Train Loss: 0.0552, Val Loss: 0.0548, Time: 242.47s
# Validation loss decreased (0.054808 --> 0.053713). Saving model...
# Validation loss decreased (0.053713 --> 0.052758). Saving model...
# Validation loss decreased (0.052758 --> 0.051468). Saving model...
# Validation loss decreased (0.051468 --> 0.050514). Saving model...
# Validation loss decreased (0.050514 --> 0.049476). Saving model...
# Validation loss decreased (0.049476 --> 0.049007). Saving model...
# Validation loss decreased (0.049007 --> 0.048051). Saving model...
# Validation loss decreased (0.048051 --> 0.046992). Saving model...
# Validation loss decreased (0.046992 --> 0.045920). Saving model...
# Validation loss decreased (0.045920 --> 0.045391). Saving model...
# Epoch 140, Train Loss: 0.0463, Val Loss: 0.0454, Time: 261.51s
# Validation loss decreased (0.045391 --> 0.044246). Saving model...
# Validation loss decreased (0.044246 --> 0.043597). Saving model...
# Validation loss decreased (0.043597 --> 0.042845). Saving model...
# Validation loss decreased (0.042845 --> 0.042820). Saving model...
# Validation loss decreased (0.042820 --> 0.041604). Saving model...
# Validation loss decreased (0.041604 --> 0.041558). Saving model...
# Validation loss decreased (0.041558 --> 0.040033). Saving model...
# Validation loss decreased (0.040033 --> 0.039413). Saving model...
# Validation loss decreased (0.039413 --> 0.038700). Saving model...
# Validation loss decreased (0.038700 --> 0.038088). Saving model...
# Epoch 150, Train Loss: 0.0386, Val Loss: 0.0381, Time: 280.41s
# Test Loss: 0.0377, RMSE: 0.1947, MAE: 0.1263, R2 Score: -6.6910
# Total training time: 280.60 seconds
# すべての学習プロセスが完了しました。次のステップ:
# - モデルのパフォーマンスをテストデータで確認
# - 保存したモデルやハイパーパラメータのレビュー
# - 必要であればモデルの微調整（例: 新しいハイパーパラメータのテスト）

# %%
import os
import time
import json
import numpy as np
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader  # 修正
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from torch.utils.tensorboard import SummaryWriter

if torch.cuda.is_available():
    print("GPU is available")
    print(f"Using device: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available, using CPU")
    
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")


# データフォルダ
standardized_data_folder = "/home/nishioka/GNN/Defect_4x4_Standardized1"
label_data_folder = "/home/nishioka/GNN/DefectLabels_4x4_test1"

# 座標データのロード
x_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/x_2layer.npy")[:3654]
y_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/y_2layer.npy")[:3654]
z_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/z_2layer.npy")[:3654]

# エッジ情報を読み込む
edges = np.load("/home/nishioka/GNN/BasicdataforGNN/edges_2layer.npy")
edge_index = torch.tensor(edges.T, dtype=torch.long).to(device)

# データとラベルファイルを対応付け
data_files = [f for f in os.listdir(standardized_data_folder) if f.startswith("Standardized1_Defect4x4_ELNOD")]
label_files = [f for f in os.listdir(label_data_folder) if f.startswith("DefectLabel_L")]

# 欠陥なしのファイルを追加
data_files.append("0Standardized1_nodefect_4x4_ElNOD.npy")
label_files.append("0DefectLabel_nodefect1.npy")

# データとラベルのペアを取得する関数
def extract_layer_block(file_name):
    if file_name.startswith("0"):
        return (0, 0)  # 欠陥なしデータの場合
    try:
        layer_block_str = file_name.split("_")[-1].replace(".npy", "")
        layer_str = layer_block_str.split("L")[1].split("B")[0]
        block_str = layer_block_str.split("B")[1]
        layer = int(layer_str)
        block = int(block_str)
        return (layer, block)
    except (ValueError, IndexError):
        print(f"無効なファイル名の形式: {file_name}")
        return None

# データとラベルのペアを作成
data_label_pairs = {}
for data_file in data_files:
    layer_block = extract_layer_block(data_file)
    if layer_block:
        data_label_pairs[layer_block] = {"data": data_file}

for label_file in label_files:
    layer_block = extract_layer_block(label_file)
    if layer_block and layer_block in data_label_pairs:
        data_label_pairs[layer_block]["label"] = label_file

# 有効なペアのみ取得
valid_pairs = [(v["data"], v["label"]) for k, v in data_label_pairs.items() if "label" in v]

# ランダムにサンプリング
num_samples = 1296
random_indices = np.random.choice(len(valid_pairs), num_samples, replace=False)

# サンプルをトレーニングデータとして取得
train_pairs = [valid_pairs[i] for i in random_indices]

# 残りのデータを取得
remaining_pairs = [valid_pairs[i] for i in range(len(valid_pairs)) if i not in random_indices]

# 残りのデータを1:1でバリデーションとテストに分割
val_pairs, test_pairs = train_test_split(remaining_pairs, test_size=0.5, random_state=42)

# 検証データとテストデータを適切に分けて格納
train_data = [pair[0] for pair in train_pairs]
train_labels = [pair[1] for pair in train_pairs]

val_data = [pair[0] for pair in val_pairs]
val_labels = [pair[1] for pair in val_pairs]

test_data = [pair[0] for pair in test_pairs]
test_labels = [pair[1] for pair in test_pairs]

# データ準備の関数
def prepare_data(pairs):
    sampled_data = []
    sampled_labels = []
    
    for data_file, label_file in pairs:
        data_file_path = os.path.join(standardized_data_folder, data_file)
        label_file_path = os.path.join(label_data_folder, label_file)

        # データとラベルを読み込む
        values = np.load(data_file_path)[:3654]
        label = np.load(label_file_path)[:3654]
        
        # 座標データと応力データを結合してノード特徴量を作成
        node_features = np.vstack((x_coords, y_coords, z_coords, values)).T
        sampled_data.append(node_features)
        sampled_labels.append(label)
    
    # データを結合しテンソルに変換
    sampled_data = np.stack(sampled_data)
    sampled_labels = np.hstack(sampled_labels)

    x = torch.tensor(sampled_data.reshape(-1, 4), dtype=torch.float).to(device)
    y = torch.tensor(sampled_labels, dtype=torch.float).to(device)

    return x, y

# 各データセットを準備
train_x, train_y = prepare_data(train_pairs)
val_x, val_y = prepare_data(val_pairs)
test_x, test_y = prepare_data(test_pairs)

# Dataオブジェクトにまとめる
train_data = Data(x=train_x, edge_index=edge_index, y=train_y)
val_data = Data(x=val_x, edge_index=edge_index, y=val_y)
test_data = Data(x=test_x, edge_index=edge_index, y=test_y)

# Output sizes
print(f"\nDataset Sizes:")
print(f"{'Training data size:':<25} {len(train_data_list)} samples")
print(f"{'Validation data size:':<25} {len(val_data_list)} samples")
print(f"{'Test data size:':<25} {len(test_data_list)} samples")

# Detailed Data Sizes
train_sample_size = len(train_data_list) * 3654
val_sample_size = len(val_data_list) * 3654
test_sample_size = len(test_data_list) * 3654

print(f"\nDetailed Data Sizes:")
print(f"{'Training Data size:':<25} {train_data.x.size(0)} (Expected: {len(train_data_list)} * 3654 = {train_sample_size})")
print(f"{'Training Edge size:':<25} {train_data.edge_index.size(1)}")
print(f"{'Training Label size:':<25} {train_data.y.size(0)} (Expected: {len(train_data_list)} * 3654 = {train_sample_size})")

print(f"\n{'Validation Data size:':<25} {val_data.x.size(0)} (Expected: {len(val_data_list)} * 3654 = {val_sample_size})")
print(f"{'Validation Edge size:':<25} {val_data.edge_index.size(1)}")
print(f"{'Validation Label size:':<25} {val_data.y.size(0)} (Expected: {len(val_data_list)} * 3654 = {val_sample_size})")

print(f"\n{'Test Data size:':<25} {test_data.x.size(0)} (Expected: {len(test_data_list)} * 3654 = {test_sample_size})")
print(f"{'Test Edge size:':<25} {test_data.edge_index.size(1)}")
print(f"{'Test Label size:':<25} {test_data.y.size(0)} (Expected: {len(test_data_list)} * 3654 = {test_sample_size})")

# Check if defect-free data is included in the training data
if no_defect_in_train:
    print("\nDefect-free data is included in the training data.")
else:
    print("\nDefect-free data is NOT included in the training data.")

# Display detailed data pairs for Training, Validation, and Test datasets
print("\n--- Training Data Sample ---")
for i, (data_file, label_file) in enumerate(train_pairs[:2], 1):  # Display first two samples
    print(f"Sample {i}: data: {data_file}, label: {label_file}")

print("\n--- Validation Data Sample ---")
for i, (data_file, label_file) in enumerate(val_pairs[:2], 1):
    print(f"Sample {i}: data: {data_file}, label: {label_file}")

print("\n--- Test Data Sample ---")
for i, (data_file, label_file) in enumerate(test_pairs[:2], 1):
    print(f"Sample {i}: data: {data_file}, label: {label_file}")

# Xavier初期化関数
def init_weights(m):
    if isinstance(m, torch.nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight)
    elif isinstance(m, GCNConv):
        torch.nn.init.xavier_uniform_(m.lin.weight)

# GCNモデルの定義
class GCNModel(torch.nn.Module):
    def __init__(self, hidden_channels=32):
        super(GCNModel, self).__init__()
        self.conv1 = GCNConv(4, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels*2)
        self.conv3 = GCNConv(hidden_channels*2, hidden_channels)
        self.fc_defect = torch.nn.Linear(hidden_channels, 1)  # 回帰タスク用に出力1次元

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv3(x, edge_index))
        return self.fc_defect(x)
        # return F.relu(self.fc_defect(x))  # 最後の層にもReLUを適用

# ハイパーパラメータ設定
hidden_channels = 64
learning_rate = 0.00001
batch_size = 64
epochs = 1500
weight_decay = 5e-4
patience = 30  # Early Stopping用

# モデル、損失関数、オプティマイザの定義
model = GCNModel(hidden_channels=hidden_channels).to(device)
model.apply(init_weights)  # Xavier初期化
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
loss_fn = torch.nn.MSELoss()

# TensorBoardの初期化
writer = SummaryWriter(log_dir=f'/home/nishioka/GNN/GNNlogs/{timestamp}')

# Early Stopping用の変数
best_val_loss = float('inf')
counter = 0

# 学習時間の計測
start_time = time.time()

# データをサンプルごとに分割
train_data_list = []
val_data_list = []
test_data_list = []

# サンプル単位でデータをDataLoaderに渡す
num_train_samples = train_x.shape[0] // 3654  # サンプル数の計算
num_val_samples = val_x.shape[0] // 3654
num_test_samples = test_x.shape[0] // 3654

for i in range(num_train_samples):
    train_data_list.append(Data(x=train_x[i*3654:(i+1)*3654], edge_index=edge_index, y=train_y[i*3654:(i+1)*3654]))

for i in range(num_val_samples):
    val_data_list.append(Data(x=val_x[i*3654:(i+1)*3654], edge_index=edge_index, y=val_y[i*3654:(i+1)*3654]))

for i in range(num_test_samples):
    test_data_list.append(Data(x=test_x[i*3654:(i+1)*3654], edge_index=edge_index, y=test_y[i*3654:(i+1)*3654]))

# データローダーの作成
train_loader = DataLoader(train_data_list, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data_list, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data_list, batch_size=32, shuffle=False)

# EarlyStopping クラス定義
class EarlyStopping:
    """Early stopping utility to stop training when validation loss doesn't improve."""
    def __init__(self, patience=patience, verbose=False, delta=0, path='/home/nishioka/GNN/checkpoint1.pt', trace_func=print):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            # if self.verbose:
            #     self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        # if self.verbose:
        #     self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss
        
# EarlyStoppingクラスのインスタンス作成
early_stopping = EarlyStopping(patience=patience, verbose=True, path=f'/home/nishioka/GNN/GNNmodel/gcn_model_best_{timestamp}.pth')

train_losses = []
val_losses = []
test_losses = []
start_time = time.time()

print("\n--- Train Val Loss at epoch epochs={epochs}---")

# 学習ループの開始
for epoch in range(1, epochs + 1):
    model.train()
    total_loss = 0

    for batch in train_loader:
        batch.x = batch.x.to(device)
        batch.y = batch.y.to(device)
        batch.edge_index = batch.edge_index.to(device)
        optimizer.zero_grad()
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1).float().to(device))  # yをfloat型に変換してGPUに移動
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    train_losses.append(total_loss / len(train_loader))

    # 検証ステップ
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in val_loader:
            batch.x = batch.x.to(device)
            batch.y = batch.y.to(device)
            batch.edge_index = batch.edge_index.to(device)
            out = model(batch)
            loss = loss_fn(out, batch.y.view(-1, 1).float().to(device))
            val_loss += loss.item()

    val_losses.append(val_loss / len(val_loader))

    # EarlyStoppingに現在のバリデーション損失とモデルを渡す
    early_stopping(val_loss / len(val_loader), model)

    # EarlyStoppingがTrueなら訓練を終了
    if early_stopping.early_stop:
        print(f"Early stopping at epoch {epoch}")
        break

    # 1, 10, 30, 50, 100, 150, 200, 250... のタイミングで結果を出力
    if epoch == 1 or epoch == 10 or epoch == 30 or (epoch % 50 == 0):
        elapsed_time = time.time() - start_time
        print(f'Epoch {epoch}, Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, Time: {elapsed_time:.2f}s')

# # 学習と検証
# train_losses = []
# val_losses = []
# test_losses = []
# start_time = time.time()

# テストデータでの評価
test_loss = 0
test_preds = []
test_targets = []
with torch.no_grad():
    for batch in test_loader:
        batch.x = batch.x.to(device)
        batch.y = batch.y.to(device)
        batch.edge_index = batch.edge_index.to(device)
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1))
        test_loss += loss.item()
        test_preds.append(out.cpu().numpy())
        test_targets.append(batch.y.cpu().numpy())

test_loss /= len(test_loader)
test_preds = np.concatenate(test_preds)
test_targets = np.concatenate(test_targets)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(test_targets, test_preds))

# MAE (Mean Absolute Error)
mae = mean_absolute_error(test_targets, test_preds)

# R2 Score
r2 = r2_score(test_targets, test_preds)

print(f'Test Loss: {test_loss:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R2 Score: {r2:.4f}')

# TensorBoardに損失を記録
writer.add_scalar('Loss/train', train_losses[-1], epoch)
writer.add_scalar('Loss/val', val_losses[-1], epoch)
        
# 学習時間の計測終了
elapsed_time = time.time() - start_time
print(f"Total training time: {elapsed_time:.2f} seconds")

# モデル、学習結果の保存
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodel/gcn_model_final_{timestamp}.pth')

# 学習時間をファイルに保存
with open(f'/home/nishioka/GNN/GNNmodelcsv/training_time_{timestamp}.txt', 'w') as f:
    f.write(f"Total training time: {elapsed_time:.2f} seconds\n")

# 損失とその他の指標をCSVに保存
loss_data = pd.DataFrame({
    'Epoch': range(1, len(train_losses) + 1),
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})
loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/loss_data_{timestamp}.csv', index=False)


# 損失をプロット
plt.figure(figsize=(12, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', color='blue')  # train_lossesの長さに合わせる
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', color='orange')  # val_lossesの長さに合わせる
plt.yscale('log')  # 対数スケール
plt.xlabel('Epoch')
plt.ylabel('Loss (Log Scale)')
plt.title(f'Training and Validation Loss {type(model).__name__} - ({timestamp})')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.show()

# Create a figure for the plot and the table
fig, ax = plt.subplots(figsize=(10, 6))

# Remove the axes (the empty graph)
ax.axis('off')

# Data for the table
table_data = [
    ["Model", type(model).__name__],
    ["Learning Rate", learning_rate],
    ["Batch Size", batch_size],
    ["Epochs", epochs],
    ["Weight Decay", weight_decay],
    ["Patience", patience],
    ["Training Samples", num_train_samples],
    ["Validation Samples", num_val_samples],
    ["Test Samples", num_test_samples]
]

# Create the table without any plot axes
table = ax.table(cellText=table_data, colLabels=["Parameter", "Value"], loc="center", cellLoc="center")

# Adjust column widths and the table position
table.scale(1.5, 1.5)  # Scale width (1.5 times wider) and height (1.5 times taller)
table.set_fontsize(12)  # Set table font size

# Save the figure
plt.subplots_adjust(left=0.1, bottom=0.2)  # Ensure there’s enough space at the bottom for the table
plt.savefig(f'/home/nishioka/GNN/GNNmodelgraphfig/parameter_table_{timestamp}.png')
plt.show()



# モデルとハイパーパラメータをJSONに保存する例
model_params = {
    'hidden_channels': hidden_channels,
    'learning_rate': learning_rate,
    'batch_size': batch_size,
    'epochs': epochs,
    'weight_decay': weight_decay,
    'patience': patience
}
with open(f'/home/nishioka/GNN/GNNmodel/{type(model).__name__}_params_{timestamp}.json', 'w') as f:
    json.dump(model_params, f, indent=4)


# 損失とハイパーパラメータ情報をCSVに保存
loss_data = pd.DataFrame({
    'Epoch': range(1, epochs + 1),
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})
loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/loss_data_{test_loss:.4f}_{timestamp}.csv', index=False)

# ハイパーパラメータのCSV
hyperparameter_data = pd.DataFrame(table_data, columns=["Parameter", "Value"])
hyperparameter_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/hyperparameters_{test_loss:.4f}_{timestamp}.csv', index=False)

# 結果を保存
test_loss_data = pd.DataFrame({
    'Test Loss': [test_loss],
    'RMSE': [rmse],
    'MAE': [mae],
    'R2 Score': [r2]
})
test_loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/test_loss_{test_loss:.4f}_{timestamp}.csv', index=False)

# ファイル名にタイムスタンプを追加

test_loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/test_loss_{test_loss:.4f}_{timestamp}.csv', index=False)

# モデルの保存（ファイル名にタイムスタンプを追加）
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodel/{type(model).__name__}_{test_loss:.4f}_{timestamp}.pth')
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodelweights/{type(model).__name__}_weights_{test_loss:.4f}_{timestamp}.pth')

# TensorBoardのWriterを閉じる
writer.close()

# Improved Final summary after the training loop
# def print_summary(epoch, early_stop):
    print("\nTraining Summary:")
    print(f"Total Epochs Run: {epoch}")
    if early_stopping.early_stop:
        print(f"Early stopping at epoch {epoch}")
    else:
    print("Training continued without early stopping.")
    print(f"Best Epoch (Lowest Validation Loss): {epoch}")
    print(f"Final Training Loss: {train_losses[-1]:.4f}")
    print(f"Best Validation Loss: {best_val_loss:.4f}")
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"R2 Score: {r2:.4f}")
    print(f"Final Learning Rate: {learning_rate}")
    print(f"Training Samples: {num_train_samples}")
    print(f"Validation Samples: {num_val_samples}")
    print(f"Test Samples: {num_test_samples}")
    print(f"Total Training Time: {elapsed_time:.2f} seconds")
# Out:
# GPU is available
# Using device: NVIDIA GeForce RTX 3090
#
# Dataset Sizes:
# Training data size:       1296 samples
# Validation data size:     162 samples
# Test data size:           163 samples
#
# Detailed Data Sizes:
# Training Data size:       4735584 (Expected: 1296 * 3654 = 4735584)
# Training Edge size:       7124
# Training Label size:      4735584 (Expected: 1296 * 3654 = 4735584)
#
# Validation Data size:     591948 (Expected: 162 * 3654 = 591948)
# Validation Edge size:     7124
# Validation Label size:    591948 (Expected: 162 * 3654 = 591948)
#
# Test Data size:           595602 (Expected: 163 * 3654 = 595602)
# Test Edge size:           7124
# Test Label size:          595602 (Expected: 163 * 3654 = 595602)
#
# Defect-free data is included in the training data.
#
# --- Training Data Sample ---
# Sample 1: data: Standardized1_Defect4x4_ELNOD_L8B82.npy, label: DefectLabel_L8B82.npy
# Sample 2: data: Standardized1_Defect4x4_ELNOD_L13B77.npy, label: DefectLabel_L13B77.npy
#
# --- Validation Data Sample ---
# Sample 1: data: Standardized1_Defect4x4_ELNOD_L17B77.npy, label: DefectLabel_L17B77.npy
# Sample 2: data: Standardized1_Defect4x4_ELNOD_L4B43.npy, label: DefectLabel_L4B43.npy
#
# --- Test Data Sample ---
# Sample 1: data: Standardized1_Defect4x4_ELNOD_L12B45.npy, label: DefectLabel_L12B45.npy
# Sample 2: data: Standardized1_Defect4x4_ELNOD_L19B56.npy, label: DefectLabel_L19B56.npy
#
# --- Train Val Loss at epoch epochs={epochs}---
# Epoch 1, Train Loss: 349.2448, Val Loss: 226.8078, Time: 1.99s
# Epoch 10, Train Loss: 6.7245, Val Loss: 6.2770, Time: 20.43s
# Epoch 30, Train Loss: 1.3266, Val Loss: 1.2902, Time: 62.03s
# Epoch 50, Train Loss: 0.6758, Val Loss: 0.6687, Time: 103.50s
# Epoch 100, Train Loss: 0.2475, Val Loss: 0.2459, Time: 207.21s
# Epoch 150, Train Loss: 0.1095, Val Loss: 0.1106, Time: 311.28s
# Epoch 200, Train Loss: 0.0604, Val Loss: 0.0597, Time: 416.21s
# Epoch 250, Train Loss: 0.0410, Val Loss: 0.0388, Time: 520.90s
# Epoch 300, Train Loss: 0.0292, Val Loss: 0.0282, Time: 625.98s
# Epoch 350, Train Loss: 0.0223, Val Loss: 0.0230, Time: 730.77s
# Epoch 400, Train Loss: 0.0198, Val Loss: 0.0188, Time: 836.29s
# Epoch 450, Train Loss: 0.0195, Val Loss: 0.0163, Time: 941.17s
# Epoch 500, Train Loss: 0.0145, Val Loss: 0.0150, Time: 1044.77s
# Epoch 550, Train Loss: 0.0139, Val Loss: 0.0133, Time: 1148.27s
# Epoch 600, Train Loss: 0.0141, Val Loss: 0.0127, Time: 1253.65s
# Epoch 650, Train Loss: 0.0135, Val Loss: 0.0121, Time: 1359.21s
# Epoch 700, Train Loss: 0.0117, Val Loss: 0.0117, Time: 1464.71s
# Epoch 750, Train Loss: 0.0129, Val Loss: 0.0146, Time: 1570.02s
# Epoch 800, Train Loss: 0.0110, Val Loss: 0.0110, Time: 1674.78s
# Epoch 850, Train Loss: 0.0107, Val Loss: 0.0107, Time: 1779.74s
# Epoch 900, Train Loss: 0.0106, Val Loss: 0.0105, Time: 1882.28s
# Epoch 950, Train Loss: 0.0104, Val Loss: 0.0124, Time: 1985.01s
# Epoch 1000, Train Loss: 0.0101, Val Loss: 0.0100, Time: 2011.72s
# Epoch 1050, Train Loss: 0.0099, Val Loss: 0.0098, Time: 2038.44s
# Epoch 1100, Train Loss: 0.0131, Val Loss: 0.0100, Time: 2065.28s
# Epoch 1150, Train Loss: 0.0125, Val Loss: 0.0097, Time: 2092.02s
# Epoch 1200, Train Loss: 0.0093, Val Loss: 0.0093, Time: 2118.80s
# Epoch 1250, Train Loss: 0.0102, Val Loss: 0.0091, Time: 2145.42s
# Epoch 1300, Train Loss: 0.0101, Val Loss: 0.0092, Time: 2172.19s
# Epoch 1350, Train Loss: 0.0091, Val Loss: 0.0089, Time: 2198.92s
# Epoch 1400, Train Loss: 0.0133, Val Loss: 0.0094, Time: 2225.65s
# Epoch 1450, Train Loss: 0.0109, Val Loss: 0.0087, Time: 2252.34s
# Epoch 1500, Train Loss: 0.0117, Val Loss: 0.0097, Time: 2278.98s
# Test Loss: 0.0096, RMSE: 0.0985, MAE: 0.0630, R2 Score: -0.9623
# Total training time: 2279.03 seconds

# %%
print_summary
# Out:
# <function __main__.print_summary(best_epoch, early_stopped)>

# %%
    print("\nTraining Summary:")
    print(f"Total Epochs Run: {epoch}")
    
    print(f"Final Training Loss: {train_losses[-1]:.4f}")
    print(f"Best Validation Loss: {best_val_loss:.4f}")
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"R2 Score: {r2:.4f}")
    print(f"Final Learning Rate: {learning_rate}")
    print(f"Training Samples: {num_train_samples}")
    print(f"Validation Samples: {num_val_samples}")
    print(f"Test Samples: {num_test_samples}")
    print(f"Total Training Time: {elapsed_time:.2f} seconds")
# Out:
# Training Summary:
# Total Epochs Run: 1500
# Final Training Loss: 0.0117
# Best Validation Loss: inf
# Test Loss: 0.0096
# Root Mean Squared Error (RMSE): 0.0985
# Mean Absolute Error (MAE): 0.0630
# R2 Score: -0.9623
# Final Learning Rate: 1e-05
# Training Samples: 1296
# Validation Samples: 162
# Test Samples: 163
# Total Training Time: 2279.03 seconds

# %%
print("Test Targets:", test_targets[:20])
print("Test Predictions:", test_preds[:20])
# Out:
# Test Targets: [0. 0. 0. 0. 0.]
# Test Predictions: [[ 0.01053575]
#  [ 0.03426698]
#  [ 0.05255273]
#  [ 0.03112558]
#  [ 0.07008317]
#  [ 0.05534509]
#  [ 0.0098472 ]
#  [ 0.03905443]
#  [ 0.07860139]
#  [ 0.07513002]
#  [ 0.07407716]
#  [ 0.02198938]
#  [-0.02778479]
#  [ 0.0148063 ]
#  [ 0.03796724]
#  [ 0.03997949]
#  [ 0.03513864]
#  [ 0.03034166]
#  [ 0.02550844]
#  [ 0.01673082]]

# %%
def print_summary(epoch, early_stop, train_losses, best_val_loss, test_loss, rmse, mae, r2, learning_rate, num_train_samples, num_val_samples, num_test_samples, elapsed_time):
    print("\nTraining Summary:")
    print(f"Total Epochs Run: {epoch}")
    if early_stop:
        print(f"Early stopping at epoch {epoch}")
    else:
        print("Training continued without early stopping.")
    
    print(f"Best Epoch (Lowest Validation Loss): {epoch}")
    print(f"Final Training Loss: {train_losses[-1]:.4f}")
    print(f"Best Validation Loss: {best_val_loss:.4f}")
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"R2 Score: {r2:.4f}")
    print(f"Final Learning Rate: {learning_rate}")
    print(f"Training Samples: {num_train_samples}")
    print(f"Validation Samples: {num_val_samples}")
    print(f"Test Samples: {num_test_samples}")
    print(f"Total Training Time: {elapsed_time:.2f} seconds")

# %%
print_summary
# Out:
# <function __main__.print_summary(epoch, early_stop, train_losses, best_val_loss, test_loss, rmse, mae, r2, learning_rate, num_train_samples, num_val_samples, num_test_samples, elapsed_time)>

# %%
import os
import time
import json
import numpy as np
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader  # 修正
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from torch.utils.tensorboard import SummaryWriter

if torch.cuda.is_available():
    print("GPU is available")
    print(f"Using device: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available, using CPU")
    
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")


# データフォルダ
standardized_data_folder = "/home/nishioka/GNN/Defect_4x4_Normalized1"
label_data_folder = "/home/nishioka/GNN/DefectLabels_4x4_test2"

# 座標データのロード
x_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/x_2layer.npy")[:3654]
y_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/y_2layer.npy")[:3654]
z_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/z_2layer.npy")[:3654]

# エッジ情報を読み込む
edges = np.load("/home/nishioka/GNN/BasicdataforGNN/edges_2layer.npy")
edge_index = torch.tensor(edges.T, dtype=torch.long).to(device)

# データとラベルファイルを対応付け
data_files = [f for f in os.listdir(standardized_data_folder) if f.startswith("Normalized1_Defect4x4_ELNOD")]
label_files = [f for f in os.listdir(label_data_folder) if f.startswith("DefectLabel2_L")]

# 欠陥なしのファイルを追加
data_files.append("0Normalized1_nodefect_4x4_ELNOD.npy")
label_files.append("0DefectLabel2_nodefect.npy")

# データとラベルのペアを取得する関数
def extract_layer_block(file_name):
    if file_name.startswith("0"):
        return (0, 0)  # 欠陥なしデータの場合
    try:
        layer_block_str = file_name.split("_")[-1].replace(".npy", "")
        layer_str = layer_block_str.split("L")[1].split("B")[0]
        block_str = layer_block_str.split("B")[1]
        layer = int(layer_str)
        block = int(block_str)
        return (layer, block)
    except (ValueError, IndexError):
        print(f"無効なファイル名の形式: {file_name}")
        return None

# データとラベルのペアを作成
data_label_pairs = {}
for data_file in data_files:
    layer_block = extract_layer_block(data_file)
    if layer_block:
        data_label_pairs[layer_block] = {"data": data_file}

for label_file in label_files:
    layer_block = extract_layer_block(label_file)
    if layer_block and layer_block in data_label_pairs:
        data_label_pairs[layer_block]["label"] = label_file

# 有効なペアのみ取得
valid_pairs = [(v["data"], v["label"]) for k, v in data_label_pairs.items() if "label" in v]

# ランダムにサンプリング
num_samples = 1296
random_indices = np.random.choice(len(valid_pairs), num_samples, replace=False)

# サンプルをトレーニングデータとして取得
train_pairs = [valid_pairs[i] for i in random_indices]

# 残りのデータを取得
remaining_pairs = [valid_pairs[i] for i in range(len(valid_pairs)) if i not in random_indices]

# 残りのデータを1:1でバリデーションとテストに分割
val_pairs, test_pairs = train_test_split(remaining_pairs, test_size=0.5, random_state=42)

# 検証データとテストデータを適切に分けて格納
train_data = [pair[0] for pair in train_pairs]
train_labels = [pair[1] for pair in train_pairs]

val_data = [pair[0] for pair in val_pairs]
val_labels = [pair[1] for pair in val_pairs]

test_data = [pair[0] for pair in test_pairs]
test_labels = [pair[1] for pair in test_pairs]

# データ準備の関数
def prepare_data(pairs):
    sampled_data = []
    sampled_labels = []
    
    for data_file, label_file in pairs:
        data_file_path = os.path.join(standardized_data_folder, data_file)
        label_file_path = os.path.join(label_data_folder, label_file)

        # データとラベルを読み込む
        values = np.load(data_file_path)[:3654]
        label = np.load(label_file_path)[:3654]
        
        # 座標データと応力データを結合してノード特徴量を作成
        node_features = np.vstack((x_coords, y_coords, z_coords, values)).T
        sampled_data.append(node_features)
        sampled_labels.append(label)
    
    # データを結合しテンソルに変換
    sampled_data = np.stack(sampled_data)
    sampled_labels = np.hstack(sampled_labels)

    x = torch.tensor(sampled_data.reshape(-1, 4), dtype=torch.float).to(device)
    y = torch.tensor(sampled_labels, dtype=torch.float).to(device)

    return x, y

# 各データセットを準備
train_x, train_y = prepare_data(train_pairs)
val_x, val_y = prepare_data(val_pairs)
test_x, test_y = prepare_data(test_pairs)

# Dataオブジェクトにまとめる
train_data = Data(x=train_x, edge_index=edge_index, y=train_y)
val_data = Data(x=val_x, edge_index=edge_index, y=val_y)
test_data = Data(x=test_x, edge_index=edge_index, y=test_y)

# Output sizes
print(f"\nDataset Sizes:")
print(f"{'Training data size:':<25} {len(train_data_list)} samples")
print(f"{'Validation data size:':<25} {len(val_data_list)} samples")
print(f"{'Test data size:':<25} {len(test_data_list)} samples")

# Detailed Data Sizes
train_sample_size = len(train_data_list) * 3654
val_sample_size = len(val_data_list) * 3654
test_sample_size = len(test_data_list) * 3654

print(f"\nDetailed Data Sizes:")
print(f"{'Training Data size:':<25} {train_data.x.size(0)} (Expected: {len(train_data_list)} * 3654 = {train_sample_size})")
print(f"{'Training Edge size:':<25} {train_data.edge_index.size(1)}")
print(f"{'Training Label size:':<25} {train_data.y.size(0)} (Expected: {len(train_data_list)} * 3654 = {train_sample_size})")

print(f"\n{'Validation Data size:':<25} {val_data.x.size(0)} (Expected: {len(val_data_list)} * 3654 = {val_sample_size})")
print(f"{'Validation Edge size:':<25} {val_data.edge_index.size(1)}")
print(f"{'Validation Label size:':<25} {val_data.y.size(0)} (Expected: {len(val_data_list)} * 3654 = {val_sample_size})")

print(f"\n{'Test Data size:':<25} {test_data.x.size(0)} (Expected: {len(test_data_list)} * 3654 = {test_sample_size})")
print(f"{'Test Edge size:':<25} {test_data.edge_index.size(1)}")
print(f"{'Test Label size:':<25} {test_data.y.size(0)} (Expected: {len(test_data_list)} * 3654 = {test_sample_size})")

# Check if defect-free data is included in the training data
if no_defect_in_train:
    print("\nDefect-free data is included in the training data.")
else:
    print("\nDefect-free data is NOT included in the training data.")

# Display detailed data pairs for Training, Validation, and Test datasets
print("\n--- Training Data Sample ---")
for i, (data_file, label_file) in enumerate(train_pairs[:2], 1):  # Display first two samples
    print(f"Sample {i}: data: {data_file}, label: {label_file}")

print("\n--- Validation Data Sample ---")
for i, (data_file, label_file) in enumerate(val_pairs[:2], 1):
    print(f"Sample {i}: data: {data_file}, label: {label_file}")

print("\n--- Test Data Sample ---")
for i, (data_file, label_file) in enumerate(test_pairs[:2], 1):
    print(f"Sample {i}: data: {data_file}, label: {label_file}")

# Xavier初期化関数
def init_weights(m):
    if isinstance(m, torch.nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight)
    elif isinstance(m, GCNConv):
        torch.nn.init.xavier_uniform_(m.lin.weight)

# GCNモデルの定義
class GCNModel(torch.nn.Module):
    def __init__(self, hidden_channels=32):
        super(GCNModel, self).__init__()
        self.conv1 = GCNConv(4, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels*2)
        self.conv3 = GCNConv(hidden_channels*2, hidden_channels)
        self.fc_defect = torch.nn.Linear(hidden_channels, 1)  # 回帰タスク用に出力1次元

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv3(x, edge_index))
        return self.fc_defect(x)
        # return F.relu(self.fc_defect(x))  # 最後の層にもReLUを適用

# ハイパーパラメータ設定
hidden_channels = 32
learning_rate = 0.0001
batch_size = 64
epochs = 1500
weight_decay = 5e-4
patience = 50  # Early Stopping用

# モデル、損失関数、オプティマイザの定義
model = GCNModel(hidden_channels=hidden_channels).to(device)
model.apply(init_weights)  # Xavier初期化
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
loss_fn = torch.nn.MSELoss()

# TensorBoardの初期化
writer = SummaryWriter(log_dir=f'/home/nishioka/GNN/GNNlogs/{timestamp}')

# Early Stopping用の変数
best_val_loss = float('inf')
counter = 0

# 学習時間の計測
start_time = time.time()

# データをサンプルごとに分割
train_data_list = []
val_data_list = []
test_data_list = []

# サンプル単位でデータをDataLoaderに渡す
num_train_samples = train_x.shape[0] // 3654  # サンプル数の計算
num_val_samples = val_x.shape[0] // 3654
num_test_samples = test_x.shape[0] // 3654

for i in range(num_train_samples):
    train_data_list.append(Data(x=train_x[i*3654:(i+1)*3654], edge_index=edge_index, y=train_y[i*3654:(i+1)*3654]))

for i in range(num_val_samples):
    val_data_list.append(Data(x=val_x[i*3654:(i+1)*3654], edge_index=edge_index, y=val_y[i*3654:(i+1)*3654]))

for i in range(num_test_samples):
    test_data_list.append(Data(x=test_x[i*3654:(i+1)*3654], edge_index=edge_index, y=test_y[i*3654:(i+1)*3654]))

# データローダーの作成
train_loader = DataLoader(train_data_list, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data_list, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data_list, batch_size=32, shuffle=False)

# EarlyStopping クラス定義
class EarlyStopping:
    """Early stopping utility to stop training when validation loss doesn't improve."""
    def __init__(self, patience=patience, verbose=False, delta=0, path='/home/nishioka/GNN/checkpoint1.pt', trace_func=print):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            # if self.verbose:
            #     self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        # if self.verbose:
        #     self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss
        
# EarlyStoppingクラスのインスタンス作成
early_stopping = EarlyStopping(patience=patience, verbose=True, path=f'/home/nishioka/GNN/GNNmodel/gcn_model_best_{timestamp}.pth')

train_losses = []
val_losses = []
test_losses = []
start_time = time.time()

print("\n--- Train Val Loss at epoch epochs={epochs}---")

# 学習ループの開始
for epoch in range(1, epochs + 1):
    model.train()
    total_loss = 0

    for batch in train_loader:
        batch.x = batch.x.to(device)
        batch.y = batch.y.to(device)
        batch.edge_index = batch.edge_index.to(device)
        optimizer.zero_grad()
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1).float().to(device))  # yをfloat型に変換してGPUに移動
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    train_losses.append(total_loss / len(train_loader))

    # 検証ステップ
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in val_loader:
            batch.x = batch.x.to(device)
            batch.y = batch.y.to(device)
            batch.edge_index = batch.edge_index.to(device)
            out = model(batch)
            loss = loss_fn(out, batch.y.view(-1, 1).float().to(device))
            val_loss += loss.item()

    val_losses.append(val_loss / len(val_loader))

    # EarlyStoppingに現在のバリデーション損失とモデルを渡す
    early_stopping(val_loss / len(val_loader), model)

    # EarlyStoppingがTrueなら訓練を終了
    if early_stopping.early_stop:
        print(f"Early stopping at epoch {epoch}")
        break

    # 1, 10, 30, 50, 100, 150, 200, 250... のタイミングで結果を出力
    if epoch == 1 or epoch == 10 or epoch == 30 or (epoch % 50 == 0):
        elapsed_time = time.time() - start_time
        print(f'Epoch {epoch}, Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, Time: {elapsed_time:.2f}s')

# # 学習と検証
# train_losses = []
# val_losses = []
# test_losses = []
# start_time = time.time()

# テストデータでの評価
test_loss = 0
test_preds = []
test_targets = []
with torch.no_grad():
    for batch in test_loader:
        batch.x = batch.x.to(device)
        batch.y = batch.y.to(device)
        batch.edge_index = batch.edge_index.to(device)
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1))
        test_loss += loss.item()
        test_preds.append(out.cpu().numpy())
        test_targets.append(batch.y.cpu().numpy())

test_loss /= len(test_loader)
test_preds = np.concatenate(test_preds)
test_targets = np.concatenate(test_targets)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(test_targets, test_preds))

# MAE (Mean Absolute Error)
mae = mean_absolute_error(test_targets, test_preds)

# R2 Score
r2 = r2_score(test_targets, test_preds)

print(f'Test Loss: {test_loss:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R2 Score: {r2:.4f}')

# TensorBoardに損失を記録
writer.add_scalar('Loss/train', train_losses[-1], epoch)
writer.add_scalar('Loss/val', val_losses[-1], epoch)
        
# 学習時間の計測終了
elapsed_time = time.time() - start_time
print(f"Total training time: {elapsed_time:.2f} seconds")

# モデル、学習結果の保存
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodel/gcn_model_final_{timestamp}.pth')

# 学習時間をファイルに保存
with open(f'/home/nishioka/GNN/GNNmodelcsv/training_time_{timestamp}.txt', 'w') as f:
    f.write(f"Total training time: {elapsed_time:.2f} seconds\n")

# 損失とその他の指標をCSVに保存
loss_data = pd.DataFrame({
    'Epoch': range(1, len(train_losses) + 1),
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})
loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/loss_data_{timestamp}.csv', index=False)


# 損失をプロット
plt.figure(figsize=(12, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', color='blue')  # train_lossesの長さに合わせる
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', color='orange')  # val_lossesの長さに合わせる
plt.yscale('log')  # 対数スケール
plt.xlabel('Epoch')
plt.ylabel('Loss (Log Scale)')
plt.title(f'Training and Validation Loss {type(model).__name__} - ({timestamp})')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.show()

# Create a figure for the plot and the table
fig, ax = plt.subplots(figsize=(10, 6))

# Remove the axes (the empty graph)
ax.axis('off')

# Data for the table
table_data = [
    ["Model", type(model).__name__],
    ["Learning Rate", learning_rate],
    ["Batch Size", batch_size],
    ["Epochs", epochs],
    ["Weight Decay", weight_decay],
    ["Patience", patience],
    ["Training Samples", num_train_samples],
    ["Validation Samples", num_val_samples],
    ["Test Samples", num_test_samples]
]

# Create the table without any plot axes
table = ax.table(cellText=table_data, colLabels=["Parameter", "Value"], loc="center", cellLoc="center")

# Adjust column widths and the table position
table.scale(1.5, 1.5)  # Scale width (1.5 times wider) and height (1.5 times taller)
table.set_fontsize(12)  # Set table font size

# Save the figure
plt.subplots_adjust(left=0.1, bottom=0.2)  # Ensure there’s enough space at the bottom for the table
plt.savefig(f'/home/nishioka/GNN/GNNmodelgraphfig/parameter_table_{timestamp}.png')
plt.show()



# モデルとハイパーパラメータをJSONに保存する例
model_params = {
    'hidden_channels': hidden_channels,
    'learning_rate': learning_rate,
    'batch_size': batch_size,
    'epochs': epochs,
    'weight_decay': weight_decay,
    'patience': patience
}
with open(f'/home/nishioka/GNN/GNNmodel/{type(model).__name__}_params_{timestamp}.json', 'w') as f:
    json.dump(model_params, f, indent=4)


# 損失とハイパーパラメータ情報をCSVに保存
loss_data = pd.DataFrame({
    'Epoch': range(1, epochs + 1),
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})
loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/loss_data_{test_loss:.4f}_{timestamp}.csv', index=False)

# ハイパーパラメータのCSV
hyperparameter_data = pd.DataFrame(table_data, columns=["Parameter", "Value"])
hyperparameter_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/hyperparameters_{test_loss:.4f}_{timestamp}.csv', index=False)

# 結果を保存
test_loss_data = pd.DataFrame({
    'Test Loss': [test_loss],
    'RMSE': [rmse],
    'MAE': [mae],
    'R2 Score': [r2]
})
test_loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/test_loss_{test_loss:.4f}_{timestamp}.csv', index=False)

# ファイル名にタイムスタンプを追加

test_loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/test_loss_{test_loss:.4f}_{timestamp}.csv', index=False)

# モデルの保存（ファイル名にタイムスタンプを追加）
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodel/{type(model).__name__}_{test_loss:.4f}_{timestamp}.pth')
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodelweights/{type(model).__name__}_weights_{test_loss:.4f}_{timestamp}.pth')

# TensorBoardのWriterを閉じる
writer.close()

# Improved Final summary after the training loop
# def print_summary(epoch, early_stop):
print("\nTraining Summary:")
print(f"Total Epochs Run: {epoch}")
if early_stopping.early_stop:
    print(f"Early stopping at epoch {epoch}")
else:
    print("Training continued without early stopping.")
print(f"Best Epoch (Lowest Validation Loss): {epoch}")
print(f"Final Training Loss: {train_losses[-1]:.4f}")
print(f"Best Validation Loss: {best_val_loss:.4f}")
print(f"Test Loss: {test_loss:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R2 Score: {r2:.4f}")
print(f"Final Learning Rate: {learning_rate}")
print(f"Training Samples: {num_train_samples}")
print(f"Validation Samples: {num_val_samples}")
print(f"Test Samples: {num_test_samples}")
print(f"Total Training Time: {elapsed_time:.2f} seconds")
# Out:
# GPU is available
# Using device: NVIDIA GeForce RTX 3090
#
# Dataset Sizes:
# Training data size:       1296 samples
# Validation data size:     162 samples
# Test data size:           163 samples
#
# Detailed Data Sizes:
# Training Data size:       4735584 (Expected: 1296 * 3654 = 4735584)
# Training Edge size:       7124
# Training Label size:      4735584 (Expected: 1296 * 3654 = 4735584)
#
# Validation Data size:     591948 (Expected: 162 * 3654 = 591948)
# Validation Edge size:     7124
# Validation Label size:    591948 (Expected: 162 * 3654 = 591948)
#
# Test Data size:           595602 (Expected: 163 * 3654 = 595602)
# Test Edge size:           7124
# Test Label size:          595602 (Expected: 163 * 3654 = 595602)
#
# Defect-free data is included in the training data.
#
# --- Training Data Sample ---
# Sample 1: data: Normalized1_Defect4x4_ELNOD_L12B70.npy, label: DefectLabel2_L12B70.npy
# Sample 2: data: Normalized1_Defect4x4_ELNOD_L13B26.npy, label: DefectLabel2_L13B26.npy
#
# --- Validation Data Sample ---
# Sample 1: data: Normalized1_Defect4x4_ELNOD_L18B19.npy, label: DefectLabel2_L18B19.npy
# Sample 2: data: Normalized1_Defect4x4_ELNOD_L15B20.npy, label: DefectLabel2_L15B20.npy
#
# --- Test Data Sample ---
# Sample 1: data: Normalized1_Defect4x4_ELNOD_L18B82.npy, label: DefectLabel2_L18B82.npy
# Sample 2: data: Normalized1_Defect4x4_ELNOD_L2B79.npy, label: DefectLabel2_L2B79.npy
#
# --- Train Val Loss at epoch epochs={epochs}---
# Epoch 1, Train Loss: 85828.8560, Val Loss: 43852.5000, Time: 0.41s
# Epoch 10, Train Loss: 31.3138, Val Loss: 27.6637, Time: 3.92s
# Epoch 30, Train Loss: 6.4695, Val Loss: 6.3422, Time: 11.64s
# Epoch 50, Train Loss: 2.9246, Val Loss: 2.8633, Time: 19.50s
# Epoch 100, Train Loss: 0.4347, Val Loss: 0.4305, Time: 38.89s
# Epoch 150, Train Loss: 0.0953, Val Loss: 0.0944, Time: 57.97s
# Epoch 200, Train Loss: 0.0485, Val Loss: 0.0483, Time: 77.23s
# Epoch 250, Train Loss: 0.0272, Val Loss: 0.0261, Time: 96.38s
# Epoch 300, Train Loss: 0.0276, Val Loss: 0.0165, Time: 115.43s
# Epoch 350, Train Loss: 0.0138, Val Loss: 0.0175, Time: 134.41s
# Epoch 400, Train Loss: 0.0101, Val Loss: 0.0096, Time: 153.46s
# Epoch 450, Train Loss: 0.0271, Val Loss: 0.0083, Time: 172.45s
# Epoch 500, Train Loss: 0.0372, Val Loss: 0.0471, Time: 191.40s
# Epoch 550, Train Loss: 0.0355, Val Loss: 0.0086, Time: 210.28s
# Epoch 600, Train Loss: 0.0093, Val Loss: 0.0171, Time: 229.21s
# Epoch 650, Train Loss: 0.0083, Val Loss: 0.0111, Time: 248.06s
# Epoch 700, Train Loss: 0.0080, Val Loss: 0.0200, Time: 267.00s
# Epoch 750, Train Loss: 0.0378, Val Loss: 0.0626, Time: 286.01s
# Epoch 800, Train Loss: 0.0064, Val Loss: 0.0073, Time: 305.05s
# Epoch 850, Train Loss: 0.0641, Val Loss: 0.0068, Time: 323.99s
# Epoch 900, Train Loss: 0.0225, Val Loss: 0.0061, Time: 342.92s
# Epoch 950, Train Loss: 0.0064, Val Loss: 0.0067, Time: 361.91s
# Epoch 1000, Train Loss: 0.0152, Val Loss: 0.0072, Time: 380.89s
# Epoch 1050, Train Loss: 0.0060, Val Loss: 0.0057, Time: 399.86s
# Epoch 1100, Train Loss: 0.0227, Val Loss: 0.0791, Time: 419.00s
# Epoch 1150, Train Loss: 0.0056, Val Loss: 0.0057, Time: 437.97s
# Early stopping at epoch 1179
# Test Loss: 0.0325, RMSE: 0.1801, MAE: 0.1730, R2 Score: -5.8200
# Total training time: 448.95 seconds
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 464
#     460     json.dump(model_params, f, indent=4)
#     463 # 損失とハイパーパラメータ情報をCSVに保存
# --> 464 loss_data = pd.DataFrame({
#     465     'Epoch': range(1, epochs + 1),
#     466     'Training Loss': train_losses,
#     467     'Validation Loss': val_losses
#     468 })
#     469 loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/loss_data_{test_loss:.4f}_{timestamp}.csv', index=False)
#     471 # ハイパーパラメータのCSV
#
# File ~/miniconda3/envs/interstage_gnn_first/lib/python3.12/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~/miniconda3/envs/interstage_gnn_first/lib/python3.12/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/miniconda3/envs/interstage_gnn_first/lib/python3.12/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~/miniconda3/envs/interstage_gnn_first/lib/python3.12/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
print(f"Length of epochs: {epochs}")
print(f"Length of train_losses: {len(train_losses)}")
print(f"Length of val_losses: {len(val_losses)}")
# Out:
# Length of epochs: 1500
# Length of train_losses: 1179
# Length of val_losses: 1179

# %%
if early_stopping.early_stop:
        print(f"Early stopping at epoch {epoch}")
    print(f"Length of epochs: {epochs}")
# Out:
#   File <string>:3
#     print(f"Length of epochs: {epochs}")
#                                         ^
# IndentationError: unindent does not match any outer indentation level

# %%
stopped_epoch = None  # 初期化

# Early Stopping がトリガーされた時点のエポック数を取得
if early_stopping.early_stop:
    epochs = stopped_epoch  # early_stopping で止まったエポック数に変更

# リストの長さをトリミングする
train_losses = train_losses[:epochs]
val_losses = val_losses[:epochs]

# DataFrame を作成
loss_data = pd.DataFrame({
    'Epoch': range(1, epochs + 1),
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})

# CSV に保存
loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/loss_data_{test_loss:.4f}_{timestamp}.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 13
#       9 val_losses = val_losses[:epochs]
#      11 # DataFrame を作成
#      12 loss_data = pd.DataFrame({
# ---> 13     'Epoch': range(1, epochs + 1),
#      14     'Training Loss': train_losses,
#      15     'Validation Loss': val_losses
#      16 })
#      18 # CSV に保存
#      19 loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/loss_data_{test_loss:.4f}_{timestamp}.csv', index=False)
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
import os
import time
import json
import numpy as np
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from torch.utils.tensorboard import SummaryWriter

# GPUの確認
if torch.cuda.is_available():
    print("GPU is available")
    print(f"Using device: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not available, using CPU")

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# データフォルダ
standardized_data_folder = "/home/nishioka/GNN/Defect_4x4_Normalized1"
label_data_folder = "/home/nishioka/GNN/DefectLabels_4x4_test2"

# 座標データのロード
x_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/x_2layer.npy")[:3654]
y_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/y_2layer.npy")[:3654]
z_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/z_2layer.npy")[:3654]

# エッジ情報を読み込む
edges = np.load("/home/nishioka/GNN/BasicdataforGNN/edges_2layer.npy")
edge_index = torch.tensor(edges.T, dtype=torch.long).to(device)

# データとラベルファイルを対応付け
data_files = [f for f in os.listdir(standardized_data_folder) if f.startswith("Normalized1_Defect4x4_ELNOD")]
label_files = [f for f in os.listdir(label_data_folder) if f.startswith("DefectLabel2_L")]

# 欠陥なしのファイルを追加
data_files.append("0Normalized1_nodefect_4x4_ELNOD.npy")
label_files.append("0DefectLabel2_nodefect.npy")

# データとラベルのペアを取得する関数
def extract_layer_block(file_name):
    if file_name.startswith("0"):
        return (0, 0)  # 欠陥なしデータの場合
    try:
        layer_block_str = file_name.split("_")[-1].replace(".npy", "")
        layer_str = layer_block_str.split("L")[1].split("B")[0]
        block_str = layer_block_str.split("B")[1]
        layer = int(layer_str)
        block = int(block_str)
        return (layer, block)
    except (ValueError, IndexError):
        print(f"無効なファイル名の形式: {file_name}")
        return None

# データとラベルのペアを作成
data_label_pairs = {}
for data_file in data_files:
    layer_block = extract_layer_block(data_file)
    if layer_block:
        data_label_pairs[layer_block] = {"data": data_file}

for label_file in label_files:
    layer_block = extract_layer_block(label_file)
    if layer_block and layer_block in data_label_pairs:
        data_label_pairs[layer_block]["label"] = label_file

# 有効なペアのみ取得
valid_pairs = [(v["data"], v["label"]) for k, v in data_label_pairs.items() if "label" in v]

# ランダムにサンプリング
num_samples = 1296
random_indices = np.random.choice(len(valid_pairs), num_samples, replace=False)

# サンプルをトレーニングデータとして取得
train_pairs = [valid_pairs[i] for i in random_indices]

# 残りのデータを取得
remaining_pairs = [valid_pairs[i] for i in range(len(valid_pairs)) if i not in random_indices]

# 残りのデータを1:1でバリデーションとテストに分割
val_pairs, test_pairs = train_test_split(remaining_pairs, test_size=0.5, random_state=42)

# 検証データとテストデータを適切に分けて格納
train_data = [pair[0] for pair in train_pairs]
train_labels = [pair[1] for pair in train_pairs]

val_data = [pair[0] for pair in val_pairs]
val_labels = [pair[1] for pair in val_pairs]

test_data = [pair[0] for pair in test_pairs]
test_labels = [pair[1] for pair in test_pairs]

# データ準備の関数
def prepare_data(pairs):
    sampled_data = []
    sampled_labels = []
    
    for data_file, label_file in pairs:
        data_file_path = os.path.join(standardized_data_folder, data_file)
        label_file_path = os.path.join(label_data_folder, label_file)

        # データとラベルを読み込む
        values = np.load(data_file_path)[:3654]
        label = np.load(label_file_path)[:3654]
        
        # 座標データと応力データを結合してノード特徴量を作成
        node_features = np.vstack((x_coords, y_coords, z_coords, values)).T
        sampled_data.append(node_features)
        sampled_labels.append(label)
    
    # データを結合しテンソルに変換
    sampled_data = np.stack(sampled_data)
    sampled_labels = np.hstack(sampled_labels)

    x = torch.tensor(sampled_data.reshape(-1, 4), dtype=torch.float).to(device)
    y = torch.tensor(sampled_labels, dtype=torch.float).to(device)

    return x, y

# 各データセットを準備
train_x, train_y = prepare_data(train_pairs)
val_x, val_y = prepare_data(val_pairs)
test_x, test_y = prepare_data(test_pairs)

# Dataオブジェクトにまとめる
train_data = Data(x=train_x, edge_index=edge_index, y=train_y)
val_data = Data(x=val_x, edge_index=edge_index, y=val_y)
test_data = Data(x=test_x, edge_index=edge_index, y=test_y)

# データローダーの作成
train_loader = DataLoader([train_data], batch_size=32, shuffle=True)
val_loader = DataLoader([val_data], batch_size=32, shuffle=False)
test_loader = DataLoader([test_data], batch_size=32, shuffle=False)

# Xavier初期化関数
def init_weights(m):
    if isinstance(m, torch.nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight)
    elif isinstance(m, GCNConv):
        torch.nn.init.xavier_uniform_(m.lin.weight)

# GCNモデルの定義
class GCNModel(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCNModel, self).__init__()
        self.conv1 = GCNConv(4, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels*2)
        self.conv3 = GCNConv(hidden_channels*2, hidden_channels)
        self.fc_defect = torch.nn.Linear(hidden_channels, 1)  # 回帰タスク用に出力1次元

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv3(x, edge_index))
        return self.fc_defect(x)

# ハイパーパラメータ設定
hidden_channels = 32
learning_rate = 0.00001
batch_size = 64
epochs = 1500
weight_decay = 5e-4
patience = 50  # Early Stopping用

# モデル、損失関数、オプティマイザの定義
model = GCNModel(hidden_channels=hidden_channels).to(device)
model.apply(init_weights)  # Xavier初期化
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
loss_fn = torch.nn.MSELoss()

# TensorBoardの初期化
writer = SummaryWriter(log_dir=f'/home/nishioka/GNN/GNNlogs/{timestamp}')

# EarlyStopping クラス定義
class EarlyStopping:
    """Early stopping utility to stop training when validation loss doesn't improve."""
    def __init__(self, patience=patience, verbose=False, delta=0, path='/home/nishioka/GNN/checkpoint1.pt', trace_func=print):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss
        
# EarlyStoppingクラスのインスタンス作成
early_stopping = EarlyStopping(patience=patience, verbose=True, path=f'/home/nishioka/GNN/GNNmodel/gcn_model_best_{timestamp}.pth')

train_losses = []
val_losses = []
test_losses = []
start_time = time.time()

# 学習ループの開始
for epoch in range(1, epochs + 1):
    model.train()
    total_loss = 0

    for batch in train_loader:
        batch.x = batch.x.to(device)
        batch.y = batch.y.to(device)
        batch.edge_index = batch.edge_index.to(device)
        optimizer.zero_grad()
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1).float().to(device))  # yをfloat型に変換してGPUに移動
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    train_losses.append(total_loss / len(train_loader))

    # 検証ステップ
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in val_loader:
            batch.x = batch.x.to(device)
            batch.y = batch.y.to(device)
            batch.edge_index = batch.edge_index.to(device)
            out = model(batch)
            loss = loss_fn(out, batch.y.view(-1, 1).float().to(device))
            val_loss += loss.item()

    val_losses.append(val_loss / len(val_loader))

    # EarlyStoppingに現在のバリデーション損失とモデルを渡す
    early_stopping(val_loss / len(val_loader), model)

    # EarlyStoppingがTrueなら訓練を終了
    if early_stopping.early_stop:
        print(f"Early stopping at epoch {epoch}")
        stopped_epoch = epoch
        break
    else:
        stopped_epoch = epochs

    # 1, 10, 30, 50, 100, 150, 200, 250... のタイミングで結果を出力
    if epoch == 1 or epoch == 10 or epoch == 30 or (epoch % 50 == 0):
        elapsed_time = time.time() - start_time
        print(f'Epoch {epoch}, Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, Time: {elapsed_time:.2f}s')

# テストデータでの評価
test_loss = 0
test_preds = []
test_targets = []
with torch.no_grad():
    for batch in test_loader:
        batch.x = batch.x.to(device)
        batch.y = batch.y.to(device)
        batch.edge_index = batch.edge_index.to(device)
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1))
        test_loss += loss.item()
        test_preds.append(out.cpu().numpy())
        test_targets.append(batch.y.cpu().numpy())

test_loss /= len(test_loader)
test_preds = np.concatenate(test_preds)
test_targets = np.concatenate(test_targets)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(test_targets, test_preds))

# MAE (Mean Absolute Error)
mae = mean_absolute_error(test_targets, test_preds)

# R2 Score
r2 = r2_score(test_targets, test_preds)

print(f'Test Loss: {test_loss:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, R2 Score: {r2:.4f}')

# TensorBoardに損失を記録
writer.add_scalar('Loss/train', train_losses[-1], stopped_epoch)
writer.add_scalar('Loss/val', val_losses[-1], stopped_epoch)
        
# 学習時間の計測終了
elapsed_time = time.time() - start_time
print(f"Total training time: {elapsed_time:.2f} seconds")

# モデル、学習結果の保存
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodel/gcn_model_final_{timestamp}.pth')

# 損失とハイパーパラメータ情報をCSVに保存
loss_data = pd.DataFrame({
    'Epoch': range(1, stopped_epoch + 1),
    'Training Loss': train_losses[:stopped_epoch],
    'Validation Loss': val_losses[:stopped_epoch]
})
loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/loss_data_{timestamp}.csv', index=False)


# TensorBoardに損失を記録
writer.add_scalar('Loss/train', train_losses[-1], epoch)
writer.add_scalar('Loss/val', val_losses[-1], epoch)
        
# 学習時間の計測終了
elapsed_time = time.time() - start_time
print(f"Total training time: {elapsed_time:.2f} seconds")

# モデル、学習結果の保存
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodel/gcn_model_final_{timestamp}.pth')

# 学習時間をファイルに保存
with open(f'/home/nishioka/GNN/GNNmodelcsv/training_time_{timestamp}.txt', 'w') as f:
    f.write(f"Total training time: {elapsed_time:.2f} seconds\n")

# 損失とその他の指標をCSVに保存
loss_data = pd.DataFrame({
    'Epoch': range(1, len(train_losses) + 1),
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})
loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/loss_data_{timestamp}.csv', index=False)


# 損失をプロット
plt.figure(figsize=(12, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', color='blue')  # train_lossesの長さに合わせる
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', color='orange')  # val_lossesの長さに合わせる
plt.yscale('log')  # 対数スケール
plt.xlabel('Epoch')
plt.ylabel('Loss (Log Scale)')
plt.title(f'Training and Validation Loss {type(model).__name__} - ({timestamp})')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.savefig(f'/home/nishioka/GNN/GNNmodelgraphfig/loss_plot_{type(model).__name__}_{timestamp}.png')  # グラフをファイルに保存
plt.show()

# Create a figure for the plot and the table
fig, ax = plt.subplots(figsize=(10, 6))

# Remove the axes (the empty graph)
ax.axis('off')

# Data for the table
table_data = [
    ["Model", type(model).__name__],
    ["Learning Rate", learning_rate],
    ["Batch Size", batch_size],
    ["Epochs", epochs],
    ["Weight Decay", weight_decay],
    ["Patience", patience],
    ["Training Samples", num_train_samples],
    ["Validation Samples", num_val_samples],
    ["Test Samples", num_test_samples]
]

# Create the table without any plot axes
table = ax.table(cellText=table_data, colLabels=["Parameter", "Value"], loc="center", cellLoc="center")

# Adjust column widths and the table position
table.scale(1.5, 1.5)  # Scale width (1.5 times wider) and height (1.5 times taller)
table.set_fontsize(12)  # Set table font size

# Save the figure
plt.subplots_adjust(left=0.1, bottom=0.2)  # Ensure there’s enough space at the bottom for the table
plt.savefig(f'/home/nishioka/GNN/GNNmodelgraphfig/parameter_table{type(model).__name__}_{timestamp}.png')
plt.show()



# モデルとハイパーパラメータをJSONに保存する例
model_params = {
    'hidden_channels': hidden_channels,
    'learning_rate': learning_rate,
    'batch_size': batch_size,
    'epochs': epochs,
    'weight_decay': weight_decay,
    'patience': patience
}
with open(f'/home/nishioka/GNN/GNNmodel/{type(model).__name__}_params_{timestamp}.json', 'w') as f:
    json.dump(model_params, f, indent=4)


# 損失とハイパーパラメータ情報をCSVに保存
loss_data = pd.DataFrame({
    'Epoch': range(1, epochs + 1),
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})
loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/loss_data_{test_loss:.4f}_{timestamp}.csv', index=False)

# ハイパーパラメータのCSV
hyperparameter_data = pd.DataFrame(table_data, columns=["Parameter", "Value"])
hyperparameter_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/hyperparameters_{test_loss:.4f}_{timestamp}.csv', index=False)

# 結果を保存
test_loss_data = pd.DataFrame({
    'Test Loss': [test_loss],
    'RMSE': [rmse],
    'MAE': [mae],
    'R2 Score': [r2]
})
test_loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/test_loss_{test_loss:.4f}_{timestamp}.csv', index=False)

# ファイル名にタイムスタンプを追加

test_loss_data.to_csv(f'/home/nishioka/GNN/GNNmodelcsv/test_loss_{test_loss:.4f}_{timestamp}.csv', index=False)

# モデルの保存（ファイル名にタイムスタンプを追加）
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodel/{type(model).__name__}_{test_loss:.4f}_{timestamp}.pth')
torch.save(model.state_dict(), f'/home/nishioka/GNN/GNNmodelweights/{type(model).__name__}_weights_{test_loss:.4f}_{timestamp}.pth')

# TensorBoardのWriterを閉じる
writer.close()

# Improved Final summary after the training loop
# def print_summary(epoch, early_stop):
print("\nTraining Summary:")
print(f"Total Epochs Run: {epoch}")
if early_stopping.early_stop:
    print(f"Early stopping at epoch {epoch}")
else:
    print("Training continued without early stopping.")
print(f"Best Epoch (Lowest Validation Loss): {epoch}")
print(f"Final Training Loss: {train_losses[-1]:.4f}")
print(f"Best Validation Loss: {best_val_loss:.4f}")
print(f"Test Loss: {test_loss:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R2 Score: {r2:.4f}")
print(f"Final Learning Rate: {learning_rate}")
print(f"Training Samples: {num_train_samples}")
print(f"Validation Samples: {num_val_samples}")
print(f"Test Samples: {num_test_samples}")
print(f"Total Training Time: {elapsed_time:.2f} seconds")
# 学習サマリの出力
print("\nTraining Summary:")
print(f"Total Epochs Run: {stopped_epoch}")
if early_stopping.early_stop:
    print(f"Early stopping at epoch {stopped_epoch}")
else:
    print("Training continued without early stopping.")
print(f"Final Training Loss: {train_losses[stopped_epoch-1]:.4f}")
print(f"Best Validation Loss: {val_losses[stopped_epoch-1]:.4f}")
print(f"Test Loss: {test_loss:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R2 Score: {r2:.4f}")
print(f"Total Training Time: {elapsed_time:.2f} seconds")
# Out:
# GPU is available
# Using device: NVIDIA GeForce RTX 3090
# Epoch 1500, Train Loss: 8.6549, Val Loss: 8.6281, Time: 239.46s
# Test Loss: 8.6304, RMSE: 2.9378, MAE: 1.8629, R2 Score: -1800.4788
# Total training time: 239.49 seconds
# Total training time: 239.50 seconds
# Training Summary:
# Total Epochs Run: 1500
# Training continued without early stopping.
# Best Epoch (Lowest Validation Loss): 1500
# Final Training Loss: 8.6549
# Best Validation Loss: inf
# Test Loss: 8.6304
# Root Mean Squared Error (RMSE): 2.9378
# Mean Absolute Error (MAE): 1.8629
# R2 Score: -1800.4788
# Final Learning Rate: 1e-05
# Training Samples: 1296
# Validation Samples: 162
# Test Samples: 163
# Total Training Time: 239.50 seconds
#
# Training Summary:
# Total Epochs Run: 1500
# Training continued without early stopping.
# Final Training Loss: 8.6549
# Best Validation Loss: 8.6281
# Test Loss: 8.6304
# Root Mean Squared Error (RMSE): 2.9378
# Mean Absolute Error (MAE): 1.8629
# R2 Score: -1800.4788
# Total Training Time: 239.50 seconds
