# %%
import os
import numpy as np
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data, DataLoader
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# データフォルダ
standardized_data_folder = "/home/nishioka/GNN/Defect_4x4_Standardized1"
label_data_folder = "/home/nishioka/GNN/DefectLabels_4x4_test1"

# 座標データのロード
x_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/x_2layer.npy")[:3654]
y_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/y_2layer.npy")[:3654]
z_coords = np.load("/home/nishioka/GNN/BasicdataforGNN/z_2layer.npy")[:3654]

# エッジ情報を読み込む
edges = np.load("/home/nishioka/GNN/BasicdataforGNN/edges_2layer.npy")
edge_index = torch.tensor(edges.T, dtype=torch.long)

# データとラベルのペアを取得する関数
def extract_layer_block(file_name):
    if file_name.startswith("0"):
        return (0, 0)  # 欠陥なしデータの場合
    try:
        layer_block_str = file_name.split("_")[-1].replace(".npy", "")
        layer_str = layer_block_str.split("L")[1].split("B")[0]
        block_str = layer_block_str.split("B")[1]
        layer = int(layer_str)
        block = int(block_str)
        return (layer, block)
    except (ValueError, IndexError):
        print(f"無効なファイル名の形式: {file_name}")
        return None

# データとラベルファイルを対応付け
data_files = [f for f in os.listdir(standardized_data_folder) if f.startswith("Standardized1_Defect4x4_ELNOD")]
label_files = [f for f in os.listdir(label_data_folder) if f.startswith("DefectLabel_L")]

# 欠陥なしのファイルを追加
data_files.append("0Standardized1_nodefect_4x4_ElNOD.npy")
label_files.append("0DefectLabel_nodefect1.npy")

# データとラベルのペアを作成
data_label_pairs = {}
for data_file in data_files:
    layer_block = extract_layer_block(data_file)
    if layer_block:
        data_label_pairs[layer_block] = {"data": data_file}

for label_file in label_files:
    layer_block = extract_layer_block(label_file)
    if layer_block and layer_block in data_label_pairs:
        data_label_pairs[layer_block]["label"] = label_file

# 有効なペアのみ取得
valid_pairs = [(v["data"], v["label"]) for k, v in data_label_pairs.items() if "label" in v]

# ランダムに1000個のペアをサンプリング
num_samples = 1000
random_indices = np.random.choice(len(valid_pairs), num_samples, replace=False)

# トレーニングデータと残りのデータを分ける
train_pairs = [valid_pairs[i] for i in random_indices]
remaining_pairs = [valid_pairs[i] for i in range(len(valid_pairs)) if i not in random_indices]

# 残りのデータを1:1でバリデーションとテストに分割
val_pairs, test_pairs = train_test_split(remaining_pairs, test_size=0.5, random_state=42)

# データ準備の関数
def prepare_data(pairs):
    sampled_data = []
    sampled_labels = []
    
    for data_file, label_file in pairs:
        data_file_path = os.path.join(standardized_data_folder, data_file)
        label_file_path = os.path.join(label_data_folder, label_file)

        # データとラベルを読み込む
        values = np.load(data_file_path)[:3654]
        label = np.load(label_file_path)[:3654]
        
        # 座標データと応力データを結合してノード特徴量を作成
        node_features = np.vstack((x_coords, y_coords, z_coords, values)).T
        sampled_data.append(node_features)
        sampled_labels.append(label)
    
    # データを結合しテンソルに変換
    sampled_data = np.stack(sampled_data)
    sampled_labels = np.hstack(sampled_labels)

    x = torch.tensor(sampled_data.reshape(-1, 4), dtype=torch.float)
    y = torch.tensor(sampled_labels, dtype=torch.float)  # 回帰のため

    return x, y

# 各データセットを準備
train_x, train_y = prepare_data(train_pairs)
val_x, val_y = prepare_data(val_pairs)
test_x, test_y = prepare_data(test_pairs)

# Dataオブジェクトにまとめる
train_data = Data(x=train_x, edge_index=edge_index, y=train_y)
val_data = Data(x=val_x, edge_index=edge_index, y=val_y)
test_data = Data(x=test_x, edge_index=edge_index, y=test_y)

# GCNモデル
class GCNModel(torch.nn.Module):
    def __init__(self):
        super(GCNModel, self).__init__()
        self.conv1 = GCNConv(4, 16)
        self.conv2 = GCNConv(16, 32)
        self.conv3 = GCNConv(32, 16)
        self.fc = torch.nn.Linear(16, 1)  # 回帰タスクのため出力は1次元

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv3(x, edge_index))
        return self.fc(x)

# モデル、損失関数、オプティマイザの定義
model = GCNModel()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
loss_fn = torch.nn.MSELoss()

# データをサンプルごとに分割
train_data_list = []
val_data_list = []
test_data_list = []

# サンプル単位でデータをDataLoaderに渡す
num_train_samples = train_x.shape[0] // 3654  # サンプル数の計算
num_val_samples = val_x.shape[0] // 3654
num_test_samples = test_x.shape[0] // 3654

for i in range(num_train_samples):
    train_data_list.append(Data(x=train_x[i*3654:(i+1)*3654], edge_index=edge_index, y=train_y[i*3654:(i+1)*3654]))

for i in range(num_val_samples):
    val_data_list.append(Data(x=val_x[i*3654:(i+1)*3654], edge_index=edge_index, y=val_y[i*3654:(i+1)*3654]))

for i in range(num_test_samples):
    test_data_list.append(Data(x=test_x[i*3654:(i+1)*3654], edge_index=edge_index, y=test_y[i*3654:(i+1)*3654]))

# データローダーの作成
train_loader = DataLoader(train_data_list, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data_list, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data_list, batch_size=32, shuffle=False)

# バッチの形状を確認
for batch in train_loader:
    print(f"Train batch X shape: {batch.x.shape}")
    print(f"Train batch Y shape: {batch.y.shape}")
    break

for batch in val_loader:
    print(f"Validation batch X shape: {batch.x.shape}")
    print(f"Validation batch Y shape: {batch.y.shape}")
    break

for batch in test_loader:
    print(f"Test batch X shape: {batch.x.shape}")
    print(f"Test batch Y shape: {batch.y.shape}")
    break

# # データローダーの作成
# train_loader = DataLoader([train_data], batch_size=32, shuffle=True)
# val_loader = DataLoader([val_data], batch_size=32, shuffle=False)
# test_loader = DataLoader([test_data], batch_size=32, shuffle=False)

# 学習と検証
train_losses = []
val_losses = []
test_losses = []

for epoch in range(1, 101):
    model.train()
    total_loss = 0
    for batch in train_loader:
        optimizer.zero_grad()
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    train_losses.append(total_loss / len(train_loader))

    # 検証
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in val_loader:
            out = model(batch)
            loss = loss_fn(out, batch.y.view(-1, 1))
            val_loss += loss.item()
    
    val_losses.append(val_loss / len(val_loader))
    print(f'Epoch {epoch}, Loss: {train_losses[-1]:.4f}, Validation Loss: {val_losses[-1]:.4f}')

# テストデータでの評価
test_loss = 0
with torch.no_grad():
    for batch in test_loader:
        out = model(batch)
        loss = loss_fn(out, batch.y.view(-1, 1))
        test_loss += loss.item()
test_loss /= len(test_loader)
print(f'Test Loss: {test_loss:.4f}')

# 損失をプロット
plt.figure(figsize=(12, 6))
plt.plot(range(1, 101), train_losses, label='Training Loss', color='blue')
plt.plot(range(1, 101), val_losses, label='Validation Loss', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid()
plt.show()

# テストロスを出力
print(f'Test Loss: {test_loss:.4f}')

# モデルの保存
torch.save(model.state_dict(), 'gcn_model.pth')

# 保存したパラメータを読み込む
model.load_state_dict(torch.load('gcn_model.pth'))

print(model)
# Out:
# Train batch X shape: torch.Size([116928, 4])
# Train batch Y shape: torch.Size([116928])
# Validation batch X shape: torch.Size([116928, 4])
# Validation batch Y shape: torch.Size([116928])
# Test batch X shape: torch.Size([116928, 4])
# Test batch Y shape: torch.Size([116928])
# Epoch 1, Loss: 204.9951, Validation Loss: 3.7144
# Epoch 2, Loss: 1.0564, Validation Loss: 0.2048
# Epoch 3, Loss: 0.1527, Validation Loss: 0.1219
# Epoch 4, Loss: 0.1066, Validation Loss: 0.0924
# Epoch 5, Loss: 0.0825, Validation Loss: 0.0736
# Epoch 6, Loss: 0.0672, Validation Loss: 0.0614
# Epoch 7, Loss: 0.0571, Validation Loss: 0.0531
# Epoch 8, Loss: 0.0499, Validation Loss: 0.0470
# Epoch 9, Loss: 0.0445, Validation Loss: 0.0422
# Epoch 10, Loss: 0.0401, Validation Loss: 0.0381
# Epoch 11, Loss: 0.0363, Validation Loss: 0.0346
# Epoch 12, Loss: 0.0330, Validation Loss: 0.0315
# Epoch 13, Loss: 0.0300, Validation Loss: 0.0286
# Epoch 14, Loss: 0.0273, Validation Loss: 0.0261
# Epoch 15, Loss: 0.0249, Validation Loss: 0.0238
# Epoch 16, Loss: 0.0228, Validation Loss: 0.0218
# Epoch 17, Loss: 0.0209, Validation Loss: 0.0200
# Epoch 18, Loss: 0.0193, Validation Loss: 0.0185
# Epoch 19, Loss: 0.0178, Validation Loss: 0.0171
# Epoch 20, Loss: 0.0166, Validation Loss: 0.0160
# Epoch 21, Loss: 0.0155, Validation Loss: 0.0150
# Epoch 22, Loss: 0.0145, Validation Loss: 0.0141
# Epoch 23, Loss: 0.0137, Validation Loss: 0.0133
# Epoch 24, Loss: 0.0129, Validation Loss: 0.0126
# Epoch 25, Loss: 0.0123, Validation Loss: 0.0120
# Epoch 26, Loss: 0.0118, Validation Loss: 0.0115
# Epoch 27, Loss: 0.0112, Validation Loss: 0.0110
# Epoch 28, Loss: 0.0108, Validation Loss: 0.0106
# Epoch 29, Loss: 0.0104, Validation Loss: 0.0102
# Epoch 30, Loss: 0.0100, Validation Loss: 0.0098
# Epoch 31, Loss: 0.0096, Validation Loss: 0.0095
# Epoch 32, Loss: 0.0093, Validation Loss: 0.0092
# Epoch 33, Loss: 0.0090, Validation Loss: 0.0089
# Epoch 34, Loss: 0.0088, Validation Loss: 0.0087
# Epoch 35, Loss: 0.0086, Validation Loss: 0.0085
# Epoch 36, Loss: 0.0084, Validation Loss: 0.0083
# Epoch 37, Loss: 0.0082, Validation Loss: 0.0081
# Epoch 38, Loss: 0.0080, Validation Loss: 0.0080
# Epoch 39, Loss: 0.0079, Validation Loss: 0.0078
# Epoch 40, Loss: 0.0077, Validation Loss: 0.0076
# Epoch 41, Loss: 0.0076, Validation Loss: 0.0075
# Epoch 42, Loss: 0.0075, Validation Loss: 0.0074
# Epoch 43, Loss: 0.0073, Validation Loss: 0.0073
# Epoch 44, Loss: 0.0073, Validation Loss: 0.0072
# Epoch 45, Loss: 0.0072, Validation Loss: 0.0071
# Epoch 46, Loss: 0.0071, Validation Loss: 0.0071
# Epoch 47, Loss: 0.0070, Validation Loss: 0.0070
# Epoch 48, Loss: 0.0070, Validation Loss: 0.0069
# Epoch 49, Loss: 0.0069, Validation Loss: 0.0069
# Epoch 50, Loss: 0.0069, Validation Loss: 0.0068
# Epoch 51, Loss: 0.0068, Validation Loss: 0.0068
# Epoch 52, Loss: 0.0067, Validation Loss: 0.0067
# Epoch 53, Loss: 0.0067, Validation Loss: 0.0067
# Epoch 54, Loss: 0.0067, Validation Loss: 0.0066
# Epoch 55, Loss: 0.0066, Validation Loss: 0.0066
# Epoch 56, Loss: 0.0066, Validation Loss: 0.0065
# Epoch 57, Loss: 0.0065, Validation Loss: 0.0065
# Epoch 58, Loss: 0.0065, Validation Loss: 0.0065
# Epoch 59, Loss: 0.0065, Validation Loss: 0.0064
# Epoch 60, Loss: 0.0064, Validation Loss: 0.0064
# Epoch 61, Loss: 0.0064, Validation Loss: 0.0064
# Epoch 62, Loss: 0.0064, Validation Loss: 0.0064
# Epoch 63, Loss: 0.0063, Validation Loss: 0.0063
# Epoch 64, Loss: 0.0063, Validation Loss: 0.0063
# Epoch 65, Loss: 0.0063, Validation Loss: 0.0063
# Epoch 66, Loss: 0.0062, Validation Loss: 0.0062
# Epoch 67, Loss: 0.0062, Validation Loss: 0.0062
# Epoch 68, Loss: 0.0062, Validation Loss: 0.0061
# Epoch 69, Loss: 0.0061, Validation Loss: 0.0061
# Epoch 70, Loss: 0.0061, Validation Loss: 0.0061
# Epoch 71, Loss: 0.0061, Validation Loss: 0.0060
# Epoch 72, Loss: 0.0060, Validation Loss: 0.0060
# Epoch 73, Loss: 0.0060, Validation Loss: 0.0060
# Epoch 74, Loss: 0.0060, Validation Loss: 0.0060
# Epoch 75, Loss: 0.0059, Validation Loss: 0.0059
# Epoch 76, Loss: 0.0059, Validation Loss: 0.0059
# Epoch 77, Loss: 0.0059, Validation Loss: 0.0059
# Epoch 78, Loss: 0.0059, Validation Loss: 0.0059
# Epoch 79, Loss: 0.0059, Validation Loss: 0.0059
# Epoch 80, Loss: 0.0058, Validation Loss: 0.0058
# Epoch 81, Loss: 0.0058, Validation Loss: 0.0058
# Epoch 82, Loss: 0.0058, Validation Loss: 0.0058
# Epoch 83, Loss: 0.0058, Validation Loss: 0.0058
# Epoch 84, Loss: 0.0058, Validation Loss: 0.0058
# Epoch 85, Loss: 0.0058, Validation Loss: 0.0058
# Epoch 86, Loss: 0.0057, Validation Loss: 0.0057
# Epoch 87, Loss: 0.0057, Validation Loss: 0.0057
# Epoch 88, Loss: 0.0057, Validation Loss: 0.0057
# Epoch 89, Loss: 0.0057, Validation Loss: 0.0057
# Epoch 90, Loss: 0.0057, Validation Loss: 0.0057
# Epoch 91, Loss: 0.0057, Validation Loss: 0.0056
# Epoch 92, Loss: 0.0056, Validation Loss: 0.0056
# Epoch 93, Loss: 0.0056, Validation Loss: 0.0056
# Epoch 94, Loss: 0.0056, Validation Loss: 0.0056
# Epoch 95, Loss: 0.0056, Validation Loss: 0.0056
# Epoch 96, Loss: 0.0056, Validation Loss: 0.0056
# Epoch 97, Loss: 0.0056, Validation Loss: 0.0055
# Epoch 98, Loss: 0.0056, Validation Loss: 0.0055
# Epoch 99, Loss: 0.0055, Validation Loss: 0.0055
# Epoch 100, Loss: 0.0055, Validation Loss: 0.0055
# Test Loss: 0.0055
# Test Loss: 0.0055
# GCNModel(
#   (conv1): GCNConv(4, 16)
#   (conv2): GCNConv(16, 32)
#   (conv3): GCNConv(32, 16)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# )
