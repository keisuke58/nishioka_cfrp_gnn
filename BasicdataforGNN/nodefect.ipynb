# %%
import numpy as np

# ファイルパス
data_file = "/home/nishioka/GNN/BasicdataforGNN/Normalized1_nodefect_ElNOD.npy"
label_file = "/home/nishioka/GNN/BasicdataforGNN/DefectLabel_nodefect.npy"

# データの読み込み
data = np.load(data_file)
label = np.load(label_file)

# shapeの確認
print(f"Data shape: {data.shape}")
print(f"Label shape: {label.shape}")
# Out:
# Data shape: (3654,)
# Label shape: (3654,)
