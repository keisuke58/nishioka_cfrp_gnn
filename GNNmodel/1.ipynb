# %% [markdown]
# import torch
#
# if torch.cuda.is_available():
#     print("GPU is available")
#     print(f"Using device: {torch.cuda.get_device_name(0)}")
# else:
#     print("GPU is not available, using CPU")

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# モデルを定義し、GPUに転送
model = GCNModel().to(device)

# データもGPUに転送
data = data.to(device)

# 推論を実行
with torch.no_grad():
    output = model(data)
dfdf
print("推論結果:", output)

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
A = torch.randn(3, 5)
A.to(device)
# Out:
# tensor([[ 0.8840,  2.1244,  2.0169,  2.0580, -0.8835],
#         [ 0.0101, -1.1122,  0.1716,  0.7085,  1.3376],
#         [ 0.3659, -1.2628, -0.1052,  0.1515,  2.6552]], device='cuda:0')

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %% [raw]
# dkfdfdf
